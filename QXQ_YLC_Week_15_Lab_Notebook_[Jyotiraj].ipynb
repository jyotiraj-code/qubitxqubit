# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotiraj-code/qubitxqubit/blob/main/QXQ_YLC_Week_15_Lab_Notebook_%5BJyotiraj%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 14: Complexity of Algorithms**
# ---
#
# ### **Description**
# Today, we will work with two of the most famous classical search algorithms: linear and binary search. We will implement and analyze their performance.
#
#
#
# <br>
#
# ### **Structure**
# ### **Structure**
# **Part 1**: [Linear Search](#p1)
#
# **Part 2**: [Binary Search](#p2)
#
#
# <br>
#
# ### **Learning Objectives**
# By the end of this lab, you will:
# * Recognize how to compare algorithms using big-O notation.
# * Recognize the limits of classical search algorithms for unordered lists.
#
#
# <br>
#
# ### **Resources**
# * [Linear Search as a Dance](http://www.youtube.com/watch?v=-PuqKbu9K3U)
#
# * [Binary Search as a Dance](http://www.youtube.com/watch?v=wz7XgKowJIg)
#
#
# <br>
#
# **Before starting, run the code below to import all necessary functions and libraries.**

# %%
# @title
# Importing other python libraries
import random
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# <a name="p1"></a>
#
# ---
# ## **Part 1: Linear Search**
# ---
#
# In this section, we will implement and analyze the linear search algorithm.

# %% [markdown]
# #### **Problem #1.1**
#
# **Together**, let's run the code below to implement linear search for a list of numbers. We will use the following variables:
# * `list_items`: A list of numbers from 0 to 49 that we will search through.
# * `marked_item`: A randomly selected number from the list that we will search for.
# * `number_queries`: A count of how many times we need to query the list to find the marked item.

# %%
list_items = range(50)
marked_item = random.choice(list_items)

print(list_items)
print(marked_item)

number_queries = 0
for item in list_items:

    number_queries = number_queries + 1

    if item == marked_item:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break
# Out:
# range(0, 50)
# 19
# 19 has been found in 20 queries.

# %% [markdown]
# #### **Problem #1.2**
#
# **Together**, let's complete the code below to run our linear search many times to find the *worst number of queries*. We will use the following additional variables:
# * `number_trials`: The number of times to repeat the linear search.
# * `worst_query`: The most number of queries we had to make across all trials.

# %%
number_trials = 1000
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  marked_item = random.choice(list_items)
  number_queries = 0
  for item in list_items:

      number_queries = number_queries + 1 # COMPLETE THIS LINE

      if item == marked_item:
          print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
          break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))
# Out:
# 23 has been found in 24 queries.
# 12 has been found in 13 queries.
# 20 has been found in 21 queries.
# 19 has been found in 20 queries.
# 42 has been found in 43 queries.
# 1 has been found in 2 queries.
# 47 has been found in 48 queries.
# 23 has been found in 24 queries.
# 31 has been found in 32 queries.
# 44 has been found in 45 queries.
# 48 has been found in 49 queries.
# 6 has been found in 7 queries.
# 6 has been found in 7 queries.
# 23 has been found in 24 queries.
# 25 has been found in 26 queries.
# 38 has been found in 39 queries.
# 33 has been found in 34 queries.
# 12 has been found in 13 queries.
# 17 has been found in 18 queries.
# 0 has been found in 1 queries.
# 39 has been found in 40 queries.
# 18 has been found in 19 queries.
# 12 has been found in 13 queries.
# 1 has been found in 2 queries.
# 12 has been found in 13 queries.
# 30 has been found in 31 queries.
# 39 has been found in 40 queries.
# 42 has been found in 43 queries.
# 8 has been found in 9 queries.
# 8 has been found in 9 queries.
# 6 has been found in 7 queries.
# 42 has been found in 43 queries.
# 31 has been found in 32 queries.
# 35 has been found in 36 queries.
# 20 has been found in 21 queries.
# 20 has been found in 21 queries.
# 10 has been found in 11 queries.
# 11 has been found in 12 queries.
# 17 has been found in 18 queries.
# 31 has been found in 32 queries.
# 25 has been found in 26 queries.
# 47 has been found in 48 queries.
# 28 has been found in 29 queries.
# 28 has been found in 29 queries.
# 19 has been found in 20 queries.
# 2 has been found in 3 queries.
# 11 has been found in 12 queries.
# 16 has been found in 17 queries.
# 9 has been found in 10 queries.
# 31 has been found in 32 queries.
# 17 has been found in 18 queries.
# 49 has been found in 50 queries.
# 29 has been found in 30 queries.
# 30 has been found in 31 queries.
# 22 has been found in 23 queries.
# 30 has been found in 31 queries.
# 4 has been found in 5 queries.
# 5 has been found in 6 queries.
# 48 has been found in 49 queries.
# 31 has been found in 32 queries.
# 25 has been found in 26 queries.
# 49 has been found in 50 queries.
# 34 has been found in 35 queries.
# 28 has been found in 29 queries.
# 42 has been found in 43 queries.
# 22 has been found in 23 queries.
# 8 has been found in 9 queries.
# 8 has been found in 9 queries.
# 39 has been found in 40 queries.
# 42 has been found in 43 queries.
# 22 has been found in 23 queries.
# 44 has been found in 45 queries.
# 7 has been found in 8 queries.
# 33 has been found in 34 queries.
# 38 has been found in 39 queries.
# 7 has been found in 8 queries.
# 35 has been found in 36 queries.
# 18 has been found in 19 queries.
# 27 has been found in 28 queries.
# 22 has been found in 23 queries.
# 9 has been found in 10 queries.
# 49 has been found in 50 queries.
# 4 has been found in 5 queries.
# 11 has been found in 12 queries.
# 0 has been found in 1 queries.
# 16 has been found in 17 queries.
# 47 has been found in 48 queries.
# 43 has been found in 44 queries.
# 43 has been found in 44 queries.
# 21 has been found in 22 queries.
# 43 has been found in 44 queries.
# 24 has been found in 25 queries.
# 40 has been found in 41 queries.
# 44 has been found in 45 queries.
# 8 has been found in 9 queries.
# 35 has been found in 36 queries.
# 3 has been found in 4 queries.
# 39 has been found in 40 queries.
# 30 has been found in 31 queries.
# 17 has been found in 18 queries.
# 38 has been found in 39 queries.
# 37 has been found in 38 queries.
# 11 has been found in 12 queries.
# 1 has been found in 2 queries.
# 29 has been found in 30 queries.
# 24 has been found in 25 queries.
# 22 has been found in 23 queries.
# 32 has been found in 33 queries.
# 44 has been found in 45 queries.
# 26 has been found in 27 queries.
# 26 has been found in 27 queries.
# 26 has been found in 27 queries.
# 47 has been found in 48 queries.
# 41 has been found in 42 queries.
# 30 has been found in 31 queries.
# 34 has been found in 35 queries.
# 11 has been found in 12 queries.
# 31 has been found in 32 queries.
# 4 has been found in 5 queries.
# 44 has been found in 45 queries.
# 3 has been found in 4 queries.
# 8 has been found in 9 queries.
# 14 has been found in 15 queries.
# 43 has been found in 44 queries.
# 20 has been found in 21 queries.
# 11 has been found in 12 queries.
# 43 has been found in 44 queries.
# 45 has been found in 46 queries.
# 42 has been found in 43 queries.
# 2 has been found in 3 queries.
# 11 has been found in 12 queries.
# 30 has been found in 31 queries.
# 36 has been found in 37 queries.
# 11 has been found in 12 queries.
# 40 has been found in 41 queries.
# 49 has been found in 50 queries.
# 6 has been found in 7 queries.
# 9 has been found in 10 queries.
# 23 has been found in 24 queries.
# 2 has been found in 3 queries.
# 14 has been found in 15 queries.
# 22 has been found in 23 queries.
# 19 has been found in 20 queries.
# 17 has been found in 18 queries.
# 34 has been found in 35 queries.
# 0 has been found in 1 queries.
# 26 has been found in 27 queries.
# 15 has been found in 16 queries.
# 13 has been found in 14 queries.
# 47 has been found in 48 queries.
# 8 has been found in 9 queries.
# 39 has been found in 40 queries.
# 12 has been found in 13 queries.
# 32 has been found in 33 queries.
# 4 has been found in 5 queries.
# 41 has been found in 42 queries.
# 10 has been found in 11 queries.
# 36 has been found in 37 queries.
# 34 has been found in 35 queries.
# 14 has been found in 15 queries.
# 24 has been found in 25 queries.
# 32 has been found in 33 queries.
# 29 has been found in 30 queries.
# 46 has been found in 47 queries.
# 23 has been found in 24 queries.
# 19 has been found in 20 queries.
# 23 has been found in 24 queries.
# 25 has been found in 26 queries.
# 12 has been found in 13 queries.
# 1 has been found in 2 queries.
# 9 has been found in 10 queries.
# 30 has been found in 31 queries.
# 37 has been found in 38 queries.
# 37 has been found in 38 queries.
# 0 has been found in 1 queries.
# 8 has been found in 9 queries.
# 5 has been found in 6 queries.
# 9 has been found in 10 queries.
# 35 has been found in 36 queries.
# 48 has been found in 49 queries.
# 48 has been found in 49 queries.
# 12 has been found in 13 queries.
# 44 has been found in 45 queries.
# 48 has been found in 49 queries.
# 39 has been found in 40 queries.
# 5 has been found in 6 queries.
# 17 has been found in 18 queries.
# 23 has been found in 24 queries.
# 37 has been found in 38 queries.
# 34 has been found in 35 queries.
# 12 has been found in 13 queries.
# 21 has been found in 22 queries.
# 41 has been found in 42 queries.
# 38 has been found in 39 queries.
# 48 has been found in 49 queries.
# 6 has been found in 7 queries.
# 48 has been found in 49 queries.
# 28 has been found in 29 queries.
# 3 has been found in 4 queries.
# 44 has been found in 45 queries.
# 34 has been found in 35 queries.
# 39 has been found in 40 queries.
# 17 has been found in 18 queries.
# 29 has been found in 30 queries.
# 11 has been found in 12 queries.
# 3 has been found in 4 queries.
# 41 has been found in 42 queries.
# 30 has been found in 31 queries.
# 37 has been found in 38 queries.
# 34 has been found in 35 queries.
# 38 has been found in 39 queries.
# 47 has been found in 48 queries.
# 47 has been found in 48 queries.
# 28 has been found in 29 queries.
# 0 has been found in 1 queries.
# 3 has been found in 4 queries.
# 12 has been found in 13 queries.
# 6 has been found in 7 queries.
# 5 has been found in 6 queries.
# 40 has been found in 41 queries.
# 10 has been found in 11 queries.
# 48 has been found in 49 queries.
# 0 has been found in 1 queries.
# 17 has been found in 18 queries.
# 3 has been found in 4 queries.
# 34 has been found in 35 queries.
# 15 has been found in 16 queries.
# 14 has been found in 15 queries.
# 4 has been found in 5 queries.
# 37 has been found in 38 queries.
# 3 has been found in 4 queries.
# 42 has been found in 43 queries.
# 7 has been found in 8 queries.
# 47 has been found in 48 queries.
# 14 has been found in 15 queries.
# 18 has been found in 19 queries.
# 20 has been found in 21 queries.
# 47 has been found in 48 queries.
# 28 has been found in 29 queries.
# 13 has been found in 14 queries.
# 21 has been found in 22 queries.
# 23 has been found in 24 queries.
# 19 has been found in 20 queries.
# 38 has been found in 39 queries.
# 42 has been found in 43 queries.
# 4 has been found in 5 queries.
# 6 has been found in 7 queries.
# 2 has been found in 3 queries.
# 37 has been found in 38 queries.
# 17 has been found in 18 queries.
# 16 has been found in 17 queries.
# 13 has been found in 14 queries.
# 9 has been found in 10 queries.
# 6 has been found in 7 queries.
# 8 has been found in 9 queries.
# 24 has been found in 25 queries.
# 25 has been found in 26 queries.
# 42 has been found in 43 queries.
# 48 has been found in 49 queries.
# 8 has been found in 9 queries.
# 7 has been found in 8 queries.
# 21 has been found in 22 queries.
# 45 has been found in 46 queries.
# 6 has been found in 7 queries.
# 25 has been found in 26 queries.
# 27 has been found in 28 queries.
# 4 has been found in 5 queries.
# 11 has been found in 12 queries.
# 37 has been found in 38 queries.
# 5 has been found in 6 queries.
# 45 has been found in 46 queries.
# 16 has been found in 17 queries.
# 18 has been found in 19 queries.
# 23 has been found in 24 queries.
# 35 has been found in 36 queries.
# 48 has been found in 49 queries.
# 9 has been found in 10 queries.
# 37 has been found in 38 queries.
# 26 has been found in 27 queries.
# 19 has been found in 20 queries.
# 13 has been found in 14 queries.
# 40 has been found in 41 queries.
# 49 has been found in 50 queries.
# 9 has been found in 10 queries.
# 45 has been found in 46 queries.
# 36 has been found in 37 queries.
# 3 has been found in 4 queries.
# 12 has been found in 13 queries.
# 13 has been found in 14 queries.
# 24 has been found in 25 queries.
# 10 has been found in 11 queries.
# 0 has been found in 1 queries.
# 10 has been found in 11 queries.
# 13 has been found in 14 queries.
# 7 has been found in 8 queries.
# 47 has been found in 48 queries.
# 7 has been found in 8 queries.
# 33 has been found in 34 queries.
# 26 has been found in 27 queries.
# 40 has been found in 41 queries.
# 36 has been found in 37 queries.
# 21 has been found in 22 queries.
# 25 has been found in 26 queries.
# 29 has been found in 30 queries.
# 29 has been found in 30 queries.
# 30 has been found in 31 queries.
# 48 has been found in 49 queries.
# 36 has been found in 37 queries.
# 21 has been found in 22 queries.
# 49 has been found in 50 queries.
# 45 has been found in 46 queries.
# 3 has been found in 4 queries.
# 42 has been found in 43 queries.
# 30 has been found in 31 queries.
# 46 has been found in 47 queries.
# 7 has been found in 8 queries.
# 43 has been found in 44 queries.
# 11 has been found in 12 queries.
# 32 has been found in 33 queries.
# 4 has been found in 5 queries.
# 49 has been found in 50 queries.
# 47 has been found in 48 queries.
# 16 has been found in 17 queries.
# 31 has been found in 32 queries.
# 0 has been found in 1 queries.
# 40 has been found in 41 queries.
# 6 has been found in 7 queries.
# 8 has been found in 9 queries.
# 13 has been found in 14 queries.
# 6 has been found in 7 queries.
# 41 has been found in 42 queries.
# 25 has been found in 26 queries.
# 1 has been found in 2 queries.
# 44 has been found in 45 queries.
# 7 has been found in 8 queries.
# 48 has been found in 49 queries.
# 34 has been found in 35 queries.
# 14 has been found in 15 queries.
# 47 has been found in 48 queries.
# 11 has been found in 12 queries.
# 48 has been found in 49 queries.
# 33 has been found in 34 queries.
# 30 has been found in 31 queries.
# 38 has been found in 39 queries.
# 0 has been found in 1 queries.
# 18 has been found in 19 queries.
# 49 has been found in 50 queries.
# 19 has been found in 20 queries.
# 22 has been found in 23 queries.
# 46 has been found in 47 queries.
# 11 has been found in 12 queries.
# 16 has been found in 17 queries.
# 11 has been found in 12 queries.
# 44 has been found in 45 queries.
# 48 has been found in 49 queries.
# 1 has been found in 2 queries.
# 32 has been found in 33 queries.
# 16 has been found in 17 queries.
# 46 has been found in 47 queries.
# 13 has been found in 14 queries.
# 9 has been found in 10 queries.
# 37 has been found in 38 queries.
# 44 has been found in 45 queries.
# 1 has been found in 2 queries.
# 20 has been found in 21 queries.
# 31 has been found in 32 queries.
# 4 has been found in 5 queries.
# 22 has been found in 23 queries.
# 32 has been found in 33 queries.
# 34 has been found in 35 queries.
# 12 has been found in 13 queries.
# 38 has been found in 39 queries.
# 41 has been found in 42 queries.
# 24 has been found in 25 queries.
# 7 has been found in 8 queries.
# 28 has been found in 29 queries.
# 5 has been found in 6 queries.
# 5 has been found in 6 queries.
# 39 has been found in 40 queries.
# 8 has been found in 9 queries.
# 19 has been found in 20 queries.
# 10 has been found in 11 queries.
# 46 has been found in 47 queries.
# 34 has been found in 35 queries.
# 35 has been found in 36 queries.
# 9 has been found in 10 queries.
# 0 has been found in 1 queries.
# 15 has been found in 16 queries.
# 25 has been found in 26 queries.
# 21 has been found in 22 queries.
# 23 has been found in 24 queries.
# 40 has been found in 41 queries.
# 48 has been found in 49 queries.
# 47 has been found in 48 queries.
# 39 has been found in 40 queries.
# 1 has been found in 2 queries.
# 18 has been found in 19 queries.
# 14 has been found in 15 queries.
# 21 has been found in 22 queries.
# 16 has been found in 17 queries.
# 19 has been found in 20 queries.
# 49 has been found in 50 queries.
# 14 has been found in 15 queries.
# 7 has been found in 8 queries.
# 8 has been found in 9 queries.
# 37 has been found in 38 queries.
# 20 has been found in 21 queries.
# 14 has been found in 15 queries.
# 44 has been found in 45 queries.
# 41 has been found in 42 queries.
# 46 has been found in 47 queries.
# 45 has been found in 46 queries.
# 21 has been found in 22 queries.
# 15 has been found in 16 queries.
# 15 has been found in 16 queries.
# 5 has been found in 6 queries.
# 7 has been found in 8 queries.
# 17 has been found in 18 queries.
# 39 has been found in 40 queries.
# 25 has been found in 26 queries.
# 6 has been found in 7 queries.
# 3 has been found in 4 queries.
# 17 has been found in 18 queries.
# 5 has been found in 6 queries.
# 4 has been found in 5 queries.
# 32 has been found in 33 queries.
# 0 has been found in 1 queries.
# 2 has been found in 3 queries.
# 33 has been found in 34 queries.
# 13 has been found in 14 queries.
# 15 has been found in 16 queries.
# 40 has been found in 41 queries.
# 34 has been found in 35 queries.
# 10 has been found in 11 queries.
# 30 has been found in 31 queries.
# 40 has been found in 41 queries.
# 17 has been found in 18 queries.
# 49 has been found in 50 queries.
# 10 has been found in 11 queries.
# 16 has been found in 17 queries.
# 16 has been found in 17 queries.
# 24 has been found in 25 queries.
# 46 has been found in 47 queries.
# 17 has been found in 18 queries.
# 49 has been found in 50 queries.
# 5 has been found in 6 queries.
# 24 has been found in 25 queries.
# 40 has been found in 41 queries.
# 27 has been found in 28 queries.
# 38 has been found in 39 queries.
# 2 has been found in 3 queries.
# 24 has been found in 25 queries.
# 31 has been found in 32 queries.
# 12 has been found in 13 queries.
# 49 has been found in 50 queries.
# 32 has been found in 33 queries.
# 8 has been found in 9 queries.
# 43 has been found in 44 queries.
# 19 has been found in 20 queries.
# 41 has been found in 42 queries.
# 6 has been found in 7 queries.
# 42 has been found in 43 queries.
# 11 has been found in 12 queries.
# 35 has been found in 36 queries.
# 28 has been found in 29 queries.
# 20 has been found in 21 queries.
# 10 has been found in 11 queries.
# 10 has been found in 11 queries.
# 31 has been found in 32 queries.
# 31 has been found in 32 queries.
# 18 has been found in 19 queries.
# 38 has been found in 39 queries.
# 7 has been found in 8 queries.
# 2 has been found in 3 queries.
# 29 has been found in 30 queries.
# 21 has been found in 22 queries.
# 34 has been found in 35 queries.
# 35 has been found in 36 queries.
# 16 has been found in 17 queries.
# 36 has been found in 37 queries.
# 39 has been found in 40 queries.
# 12 has been found in 13 queries.
# 37 has been found in 38 queries.
# 37 has been found in 38 queries.
# 5 has been found in 6 queries.
# 22 has been found in 23 queries.
# 21 has been found in 22 queries.
# 0 has been found in 1 queries.
# 9 has been found in 10 queries.
# 36 has been found in 37 queries.
# 10 has been found in 11 queries.
# 37 has been found in 38 queries.
# 4 has been found in 5 queries.
# 25 has been found in 26 queries.
# 42 has been found in 43 queries.
# 14 has been found in 15 queries.
# 7 has been found in 8 queries.
# 33 has been found in 34 queries.
# 37 has been found in 38 queries.
# 38 has been found in 39 queries.
# 39 has been found in 40 queries.
# 42 has been found in 43 queries.
# 20 has been found in 21 queries.
# 43 has been found in 44 queries.
# 23 has been found in 24 queries.
# 32 has been found in 33 queries.
# 15 has been found in 16 queries.
# 32 has been found in 33 queries.
# 1 has been found in 2 queries.
# 40 has been found in 41 queries.
# 30 has been found in 31 queries.
# 41 has been found in 42 queries.
# 19 has been found in 20 queries.
# 16 has been found in 17 queries.
# 6 has been found in 7 queries.
# 24 has been found in 25 queries.
# 40 has been found in 41 queries.
# 30 has been found in 31 queries.
# 11 has been found in 12 queries.
# 8 has been found in 9 queries.
# 22 has been found in 23 queries.
# 32 has been found in 33 queries.
# 23 has been found in 24 queries.
# 36 has been found in 37 queries.
# 17 has been found in 18 queries.
# 23 has been found in 24 queries.
# 22 has been found in 23 queries.
# 13 has been found in 14 queries.
# 1 has been found in 2 queries.
# 25 has been found in 26 queries.
# 48 has been found in 49 queries.
# 9 has been found in 10 queries.
# 41 has been found in 42 queries.
# 13 has been found in 14 queries.
# 14 has been found in 15 queries.
# 16 has been found in 17 queries.
# 41 has been found in 42 queries.
# 36 has been found in 37 queries.
# 13 has been found in 14 queries.
# 43 has been found in 44 queries.
# 1 has been found in 2 queries.
# 32 has been found in 33 queries.
# 49 has been found in 50 queries.
# 45 has been found in 46 queries.
# 4 has been found in 5 queries.
# 11 has been found in 12 queries.
# 37 has been found in 38 queries.
# 34 has been found in 35 queries.
# 9 has been found in 10 queries.
# 42 has been found in 43 queries.
# 44 has been found in 45 queries.
# 4 has been found in 5 queries.
# 1 has been found in 2 queries.
# 47 has been found in 48 queries.
# 30 has been found in 31 queries.
# 34 has been found in 35 queries.
# 47 has been found in 48 queries.
# 4 has been found in 5 queries.
# 17 has been found in 18 queries.
# 14 has been found in 15 queries.
# 1 has been found in 2 queries.
# 0 has been found in 1 queries.
# 36 has been found in 37 queries.
# 39 has been found in 40 queries.
# 44 has been found in 45 queries.
# 21 has been found in 22 queries.
# 27 has been found in 28 queries.
# 18 has been found in 19 queries.
# 23 has been found in 24 queries.
# 17 has been found in 18 queries.
# 5 has been found in 6 queries.
# 33 has been found in 34 queries.
# 25 has been found in 26 queries.
# 49 has been found in 50 queries.
# 27 has been found in 28 queries.
# 20 has been found in 21 queries.
# 28 has been found in 29 queries.
# 19 has been found in 20 queries.
# 25 has been found in 26 queries.
# 18 has been found in 19 queries.
# 19 has been found in 20 queries.
# 42 has been found in 43 queries.
# 35 has been found in 36 queries.
# 14 has been found in 15 queries.
# 24 has been found in 25 queries.
# 41 has been found in 42 queries.
# 14 has been found in 15 queries.
# 46 has been found in 47 queries.
# 41 has been found in 42 queries.
# 30 has been found in 31 queries.
# 33 has been found in 34 queries.
# 8 has been found in 9 queries.
# 38 has been found in 39 queries.
# 35 has been found in 36 queries.
# 43 has been found in 44 queries.
# 35 has been found in 36 queries.
# 27 has been found in 28 queries.
# 37 has been found in 38 queries.
# 22 has been found in 23 queries.
# 15 has been found in 16 queries.
# 31 has been found in 32 queries.
# 13 has been found in 14 queries.
# 16 has been found in 17 queries.
# 47 has been found in 48 queries.
# 39 has been found in 40 queries.
# 17 has been found in 18 queries.
# 18 has been found in 19 queries.
# 28 has been found in 29 queries.
# 29 has been found in 30 queries.
# 16 has been found in 17 queries.
# 16 has been found in 17 queries.
# 41 has been found in 42 queries.
# 13 has been found in 14 queries.
# 47 has been found in 48 queries.
# 11 has been found in 12 queries.
# 3 has been found in 4 queries.
# 48 has been found in 49 queries.
# 18 has been found in 19 queries.
# 31 has been found in 32 queries.
# 12 has been found in 13 queries.
# 29 has been found in 30 queries.
# 35 has been found in 36 queries.
# 48 has been found in 49 queries.
# 20 has been found in 21 queries.
# 40 has been found in 41 queries.
# 0 has been found in 1 queries.
# 33 has been found in 34 queries.
# 47 has been found in 48 queries.
# 41 has been found in 42 queries.
# 20 has been found in 21 queries.
# 18 has been found in 19 queries.
# 38 has been found in 39 queries.
# 30 has been found in 31 queries.
# 45 has been found in 46 queries.
# 41 has been found in 42 queries.
# 15 has been found in 16 queries.
# 48 has been found in 49 queries.
# 45 has been found in 46 queries.
# 0 has been found in 1 queries.
# 13 has been found in 14 queries.
# 10 has been found in 11 queries.
# 15 has been found in 16 queries.
# 2 has been found in 3 queries.
# 31 has been found in 32 queries.
# 28 has been found in 29 queries.
# 23 has been found in 24 queries.
# 42 has been found in 43 queries.
# 4 has been found in 5 queries.
# 0 has been found in 1 queries.
# 18 has been found in 19 queries.
# 20 has been found in 21 queries.
# 27 has been found in 28 queries.
# 22 has been found in 23 queries.
# 29 has been found in 30 queries.
# 30 has been found in 31 queries.
# 8 has been found in 9 queries.
# 31 has been found in 32 queries.
# 26 has been found in 27 queries.
# 34 has been found in 35 queries.
# 42 has been found in 43 queries.
# 4 has been found in 5 queries.
# 23 has been found in 24 queries.
# 15 has been found in 16 queries.
# 44 has been found in 45 queries.
# 15 has been found in 16 queries.
# 42 has been found in 43 queries.
# 25 has been found in 26 queries.
# 31 has been found in 32 queries.
# 19 has been found in 20 queries.
# 8 has been found in 9 queries.
# 21 has been found in 22 queries.
# 24 has been found in 25 queries.
# 12 has been found in 13 queries.
# 0 has been found in 1 queries.
# 8 has been found in 9 queries.
# 36 has been found in 37 queries.
# 23 has been found in 24 queries.
# 30 has been found in 31 queries.
# 47 has been found in 48 queries.
# 31 has been found in 32 queries.
# 14 has been found in 15 queries.
# 38 has been found in 39 queries.
# 16 has been found in 17 queries.
# 22 has been found in 23 queries.
# 36 has been found in 37 queries.
# 31 has been found in 32 queries.
# 49 has been found in 50 queries.
# 46 has been found in 47 queries.
# 14 has been found in 15 queries.
# 47 has been found in 48 queries.
# 47 has been found in 48 queries.
# 46 has been found in 47 queries.
# 46 has been found in 47 queries.
# 12 has been found in 13 queries.
# 39 has been found in 40 queries.
# 38 has been found in 39 queries.
# 15 has been found in 16 queries.
# 1 has been found in 2 queries.
# 12 has been found in 13 queries.
# 48 has been found in 49 queries.
# 21 has been found in 22 queries.
# 37 has been found in 38 queries.
# 48 has been found in 49 queries.
# 10 has been found in 11 queries.
# 27 has been found in 28 queries.
# 25 has been found in 26 queries.
# 5 has been found in 6 queries.
# 8 has been found in 9 queries.
# 35 has been found in 36 queries.
# 28 has been found in 29 queries.
# 37 has been found in 38 queries.
# 19 has been found in 20 queries.
# 14 has been found in 15 queries.
# 19 has been found in 20 queries.
# 41 has been found in 42 queries.
# 49 has been found in 50 queries.
# 22 has been found in 23 queries.
# 12 has been found in 13 queries.
# 38 has been found in 39 queries.
# 2 has been found in 3 queries.
# 28 has been found in 29 queries.
# 3 has been found in 4 queries.
# 18 has been found in 19 queries.
# 10 has been found in 11 queries.
# 9 has been found in 10 queries.
# 10 has been found in 11 queries.
# 2 has been found in 3 queries.
# 23 has been found in 24 queries.
# 23 has been found in 24 queries.
# 18 has been found in 19 queries.
# 49 has been found in 50 queries.
# 11 has been found in 12 queries.
# 19 has been found in 20 queries.
# 40 has been found in 41 queries.
# 7 has been found in 8 queries.
# 17 has been found in 18 queries.
# 23 has been found in 24 queries.
# 35 has been found in 36 queries.
# 1 has been found in 2 queries.
# 49 has been found in 50 queries.
# 17 has been found in 18 queries.
# 28 has been found in 29 queries.
# 31 has been found in 32 queries.
# 25 has been found in 26 queries.
# 23 has been found in 24 queries.
# 6 has been found in 7 queries.
# 34 has been found in 35 queries.
# 28 has been found in 29 queries.
# 46 has been found in 47 queries.
# 28 has been found in 29 queries.
# 12 has been found in 13 queries.
# 37 has been found in 38 queries.
# 35 has been found in 36 queries.
# 30 has been found in 31 queries.
# 2 has been found in 3 queries.
# 38 has been found in 39 queries.
# 4 has been found in 5 queries.
# 49 has been found in 50 queries.
# 44 has been found in 45 queries.
# 47 has been found in 48 queries.
# 44 has been found in 45 queries.
# 48 has been found in 49 queries.
# 12 has been found in 13 queries.
# 36 has been found in 37 queries.
# 38 has been found in 39 queries.
# 28 has been found in 29 queries.
# 20 has been found in 21 queries.
# 43 has been found in 44 queries.
# 2 has been found in 3 queries.
# 18 has been found in 19 queries.
# 25 has been found in 26 queries.
# 42 has been found in 43 queries.
# 8 has been found in 9 queries.
# 22 has been found in 23 queries.
# 24 has been found in 25 queries.
# 47 has been found in 48 queries.
# 33 has been found in 34 queries.
# 27 has been found in 28 queries.
# 47 has been found in 48 queries.
# 4 has been found in 5 queries.
# 36 has been found in 37 queries.
# 7 has been found in 8 queries.
# 44 has been found in 45 queries.
# 43 has been found in 44 queries.
# 15 has been found in 16 queries.
# 1 has been found in 2 queries.
# 42 has been found in 43 queries.
# 38 has been found in 39 queries.
# 2 has been found in 3 queries.
# 41 has been found in 42 queries.
# 32 has been found in 33 queries.
# 24 has been found in 25 queries.
# 25 has been found in 26 queries.
# 19 has been found in 20 queries.
# 31 has been found in 32 queries.
# 36 has been found in 37 queries.
# 9 has been found in 10 queries.
# 8 has been found in 9 queries.
# 48 has been found in 49 queries.
# 49 has been found in 50 queries.
# 46 has been found in 47 queries.
# 28 has been found in 29 queries.
# 6 has been found in 7 queries.
# 9 has been found in 10 queries.
# 36 has been found in 37 queries.
# 17 has been found in 18 queries.
# 0 has been found in 1 queries.
# 45 has been found in 46 queries.
# 44 has been found in 45 queries.
# 3 has been found in 4 queries.
# 23 has been found in 24 queries.
# 11 has been found in 12 queries.
# 25 has been found in 26 queries.
# 38 has been found in 39 queries.
# 31 has been found in 32 queries.
# 20 has been found in 21 queries.
# 31 has been found in 32 queries.
# 38 has been found in 39 queries.
# 26 has been found in 27 queries.
# 33 has been found in 34 queries.
# 6 has been found in 7 queries.
# 15 has been found in 16 queries.
# 16 has been found in 17 queries.
# 42 has been found in 43 queries.
# 23 has been found in 24 queries.
# 22 has been found in 23 queries.
# 35 has been found in 36 queries.
# 22 has been found in 23 queries.
# 16 has been found in 17 queries.
# 41 has been found in 42 queries.
# 7 has been found in 8 queries.
# 33 has been found in 34 queries.
# 11 has been found in 12 queries.
# 39 has been found in 40 queries.
# 18 has been found in 19 queries.
# 25 has been found in 26 queries.
# 17 has been found in 18 queries.
# 19 has been found in 20 queries.
# 38 has been found in 39 queries.
# 9 has been found in 10 queries.
# 30 has been found in 31 queries.
# 34 has been found in 35 queries.
# 22 has been found in 23 queries.
# 0 has been found in 1 queries.
# 31 has been found in 32 queries.
# 47 has been found in 48 queries.
# 0 has been found in 1 queries.
# 3 has been found in 4 queries.
# 18 has been found in 19 queries.
# 17 has been found in 18 queries.
# 42 has been found in 43 queries.
# 45 has been found in 46 queries.
# 39 has been found in 40 queries.
# 40 has been found in 41 queries.
# 43 has been found in 44 queries.
# 22 has been found in 23 queries.
# 10 has been found in 11 queries.
# 7 has been found in 8 queries.
# 22 has been found in 23 queries.
# 5 has been found in 6 queries.
# 44 has been found in 45 queries.
# 7 has been found in 8 queries.
# 34 has been found in 35 queries.
# 41 has been found in 42 queries.
# 21 has been found in 22 queries.
# 20 has been found in 21 queries.
# 24 has been found in 25 queries.
# 9 has been found in 10 queries.
# 5 has been found in 6 queries.
# 26 has been found in 27 queries.
# 8 has been found in 9 queries.
# 49 has been found in 50 queries.
# 31 has been found in 32 queries.
# 12 has been found in 13 queries.
# 16 has been found in 17 queries.
# 11 has been found in 12 queries.
# 48 has been found in 49 queries.
# 5 has been found in 6 queries.
# 11 has been found in 12 queries.
# 21 has been found in 22 queries.
# 46 has been found in 47 queries.
# 31 has been found in 32 queries.
# 24 has been found in 25 queries.
# 10 has been found in 11 queries.
# 9 has been found in 10 queries.
# 47 has been found in 48 queries.
# 49 has been found in 50 queries.
# 12 has been found in 13 queries.
# 33 has been found in 34 queries.
# 24 has been found in 25 queries.
# 34 has been found in 35 queries.
# 32 has been found in 33 queries.
# 1 has been found in 2 queries.
# 17 has been found in 18 queries.
# 8 has been found in 9 queries.
# 33 has been found in 34 queries.
# 0 has been found in 1 queries.
# 42 has been found in 43 queries.
# 40 has been found in 41 queries.
# 37 has been found in 38 queries.
# 17 has been found in 18 queries.
# 6 has been found in 7 queries.
# 9 has been found in 10 queries.
# 14 has been found in 15 queries.
# 45 has been found in 46 queries.
# 36 has been found in 37 queries.
# 3 has been found in 4 queries.
# 31 has been found in 32 queries.
# 25 has been found in 26 queries.
# 16 has been found in 17 queries.
# 2 has been found in 3 queries.
# 47 has been found in 48 queries.
# 32 has been found in 33 queries.
# 0 has been found in 1 queries.
# 42 has been found in 43 queries.
# 19 has been found in 20 queries.
# 47 has been found in 48 queries.
# 29 has been found in 30 queries.
# 45 has been found in 46 queries.
# 36 has been found in 37 queries.
# 37 has been found in 38 queries.
# 14 has been found in 15 queries.
# 31 has been found in 32 queries.
# 16 has been found in 17 queries.
# 44 has been found in 45 queries.
# 36 has been found in 37 queries.
# 16 has been found in 17 queries.
# 27 has been found in 28 queries.
# 9 has been found in 10 queries.
# 26 has been found in 27 queries.
# 25 has been found in 26 queries.
# 43 has been found in 44 queries.
# 9 has been found in 10 queries.
# 44 has been found in 45 queries.
# 18 has been found in 19 queries.
# 39 has been found in 40 queries.
# 21 has been found in 22 queries.
# 35 has been found in 36 queries.
# 23 has been found in 24 queries.
# 9 has been found in 10 queries.
# 26 has been found in 27 queries.
# 46 has been found in 47 queries.
# 43 has been found in 44 queries.
# 18 has been found in 19 queries.
# 8 has been found in 9 queries.
# 20 has been found in 21 queries.
# 36 has been found in 37 queries.
# 41 has been found in 42 queries.
# 24 has been found in 25 queries.
# 17 has been found in 18 queries.
# 40 has been found in 41 queries.
# 13 has been found in 14 queries.
# 30 has been found in 31 queries.
# 15 has been found in 16 queries.
# 23 has been found in 24 queries.
# 39 has been found in 40 queries.
# 1 has been found in 2 queries.
# 5 has been found in 6 queries.
# 22 has been found in 23 queries.
# 32 has been found in 33 queries.
# 46 has been found in 47 queries.
# 34 has been found in 35 queries.
# 42 has been found in 43 queries.
# 35 has been found in 36 queries.
# 40 has been found in 41 queries.
# 2 has been found in 3 queries.
# 4 has been found in 5 queries.
# 33 has been found in 34 queries.
# 30 has been found in 31 queries.
# 9 has been found in 10 queries.
# 46 has been found in 47 queries.
# 9 has been found in 10 queries.
# 29 has been found in 30 queries.
# 23 has been found in 24 queries.
# 39 has been found in 40 queries.
# 4 has been found in 5 queries.
# 6 has been found in 7 queries.
# 13 has been found in 14 queries.
# 17 has been found in 18 queries.
# 42 has been found in 43 queries.
# 9 has been found in 10 queries.
# 13 has been found in 14 queries.
# 32 has been found in 33 queries.
# 21 has been found in 22 queries.
# 6 has been found in 7 queries.
# 49 has been found in 50 queries.
# 17 has been found in 18 queries.
# 47 has been found in 48 queries.
# 1 has been found in 2 queries.
# 3 has been found in 4 queries.
# 19 has been found in 20 queries.
# 10 has been found in 11 queries.
# 49 has been found in 50 queries.
# 20 has been found in 21 queries.
# 32 has been found in 33 queries.
# 21 has been found in 22 queries.
# 5 has been found in 6 queries.
# 19 has been found in 20 queries.
# 41 has been found in 42 queries.
# 40 has been found in 41 queries.
# Worst number of queries: 50

# %% [markdown]
# #### **Problem #1.3**
#
# **Together**, let's put this code into a function called `linear_search` such that it:
# * Takes `n` as input parameters.
# * Runs the code we wrote in Exercise #2 such that there are `n` items in `list_items`.
# * Returns the worst number of queries instead of printing it.

# %%
def linear_search(n):

  # COMPLETE THIS CODE
  number_trials = 10
  worst_query = 0
  list_items = range(n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1
      if item == marked_item:
        return number_queries
        break

    worst_query = max(worst_query, number_queries)

  return worst_query# COMPLETE THIS CODE

# %% [markdown]
# ### **Problem #1.4**
#
# **Together**, let's graph the worst number of queries for list sizes from 100 to 10000.

# %%
linear_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]

plt.scatter(ns, linear_queries, label = "linear")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# []

# %% [markdown]
# <a name="p2"></a>
#
# ---
# ## **Part 2: Binary Search**
# ---
#
# In this section, we will implement and analyze the binary search algorithm. We will also visually compare it to the linear search algorithm we implemented above.

# %% [markdown]
# #### **Problem #2.1**
#
# **Together**, let's complete the code below to implement binary search for a list of numbers. We will use the following variables:
# * `list_items`: A list of numbers from 0 to 49 that we will search through.
# * `marked_item`: A randomly selected number from the list that we will search for.
# * `number_queries`: A count of how many times we need to query the list to find the marked item.

# %%
list_items = range(50)
marked_item = random.choice(list_items)

left = 0
right = len(list_items) - 1

number_queries = 0
for item in list_items:

  number_queries = number_queries  + 1# COMPLETE THIS LINE

  middle = int((left + right)/2)
  if list_items[middle] > marked_item:
    right = middle

  elif list_items[middle] < marked_item:

    left = middle
  else:
    print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
    break
# Out:
# 10 has been found in 5 queries.

# %% [markdown]
# #### **Problem #2.2**
#
# **Independently**, complete the code below to run our binary search many times to find the *worst number of queries*. You will use the following additional variables:
# * `number_trials`: The number of times to repeat the binary search.
# * `worst_query`: The most number of queries we had to make across all trials.

# %%
number_trials = 10
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  # ADD THE CODE FROM EXERCISE #1 HERE
  marked_item = random.choice(list_items)
  left = 0
  right = len(list_items) - 1
  number_queries = 0
  for items in list_items:
    number_queries = number_queries + 1
    middle = int((right + left)/2)
    if list_items[middle] > marked_item:
      right = middle
    elif list_items[middle] < marked_item:
      left = middle
    else:
      print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
      break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))
# Out:
# 2 has been found in 6 queries.
# 46 has been found in 6 queries.
# 16 has been found in 5 queries.
# 21 has been found in 4 queries.
# 22 has been found in 5 queries.
# 3 has been found in 4 queries.
# 10 has been found in 5 queries.
# 46 has been found in 6 queries.
# 6 has been found in 3 queries.
# 8 has been found in 6 queries.
# Worst number of queries: 6

# %% [markdown]
# #### **Problem #2.3**
#
# **Independently**, put this code into a function called `binary_search` such that it:
# * Takes `n` as input parameters.
# * Runs the code we wrote in Exercise #2 such that there are `n` items in `list_items`.
# * Returns the worst number of queries instead of printing it.

# %%
def binary_search(n):

  # ADD THE CODE FROM EXERCISE #1 HERE
  number_trials = 10
  worst_query = 0
  list_items = range(n)

  for i in range(number_trials):
    marked_item = random.choice(list_items)
    left = 0
    right = len(list_items) - 1
    number_queries = 0
    for item in list_items:
      number_queries = number_queries + 1
      middle = int((right + left)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle]< marked_item:
        left = middle
      else:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

  worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ---
# ####**Wait for your instructor to continue.**
#
# ---

# %% [markdown]
# #### **Problem #2.4**
#
# **Together**, graph the worst number of queries for list sizes from 100 to 10000.

# %%
# Importing  python libraries
import random
import matplotlib.pyplot as plt



binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  binary_queries += [binary_search(n)]

plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# 76 has been found in 7 queries.
# 62 has been found in 6 queries.
# 16 has been found in 6 queries.
# 6 has been found in 4 queries.
# 65 has been found in 6 queries.
# 35 has been found in 7 queries.
# 86 has been found in 3 queries.
# 7 has been found in 6 queries.
# 82 has been found in 7 queries.
# 17 has been found in 7 queries.
# 7 has been found in 7 queries.
# 102 has been found in 6 queries.
# 113 has been found in 8 queries.
# 99 has been found in 1 queries.
# 92 has been found in 5 queries.
# 16 has been found in 7 queries.
# 136 has been found in 4 queries.
# 12 has been found in 4 queries.
# 32 has been found in 8 queries.
# 40 has been found in 7 queries.
# 223 has been found in 9 queries.
# 124 has been found in 9 queries.
# 15 has been found in 7 queries.
# 37 has been found in 3 queries.
# 80 has been found in 7 queries.
# 137 has been found in 8 queries.
# 132 has been found in 7 queries.
# 18 has been found in 4 queries.
# 118 has been found in 8 queries.
# 212 has been found in 8 queries.
# 171 has been found in 9 queries.
# 33 has been found in 7 queries.
# 341 has been found in 9 queries.
# 254 has been found in 9 queries.
# 103 has been found in 8 queries.
# 327 has been found in 7 queries.
# 191 has been found in 9 queries.
# 318 has been found in 8 queries.
# 107 has been found in 9 queries.
# 15 has been found in 7 queries.
# 156 has been found in 8 queries.
# 432 has been found in 7 queries.
# 114 has been found in 8 queries.
# 398 has been found in 9 queries.
# 433 has been found in 9 queries.
# 241 has been found in 6 queries.
# 275 has been found in 9 queries.
# 486 has been found in 9 queries.
# 336 has been found in 8 queries.
# 139 has been found in 5 queries.
# 392 has been found in 5 queries.
# 515 has been found in 9 queries.
# 131 has been found in 9 queries.
# 423 has been found in 9 queries.
# 398 has been found in 8 queries.
# 192 has been found in 8 queries.
# 30 has been found in 9 queries.
# 378 has been found in 7 queries.
# 500 has been found in 7 queries.
# 75 has been found in 9 queries.
# 330 has been found in 9 queries.
# 276 has been found in 10 queries.
# 468 has been found in 10 queries.
# 265 has been found in 10 queries.
# 612 has been found in 9 queries.
# 409 has been found in 9 queries.
# 314 has been found in 9 queries.
# 419 has been found in 7 queries.
# 119 has been found in 6 queries.
# 457 has been found in 10 queries.
# 248 has been found in 10 queries.
# 407 has been found in 10 queries.
# 586 has been found in 6 queries.
# 520 has been found in 8 queries.
# 264 has been found in 8 queries.
# 72 has been found in 9 queries.
# 463 has been found in 10 queries.
# 699 has been found in 3 queries.
# 706 has been found in 9 queries.
# 788 has been found in 10 queries.
# 405 has been found in 10 queries.
# 163 has been found in 10 queries.
# 740 has been found in 8 queries.
# 602 has been found in 10 queries.
# 285 has been found in 9 queries.
# 872 has been found in 10 queries.
# 166 has been found in 9 queries.
# 879 has been found in 10 queries.
# 162 has been found in 9 queries.
# 644 has been found in 10 queries.
# 532 has been found in 10 queries.
# 720 has been found in 10 queries.
# 657 has been found in 10 queries.
# 213 has been found in 8 queries.
# 346 has been found in 8 queries.
# 274 has been found in 9 queries.
# 469 has been found in 9 queries.
# 109 has been found in 10 queries.
# 680 has been found in 9 queries.
# 855 has been found in 10 queries.
# 880 has been found in 10 queries.
# 778 has been found in 9 queries.
# 582 has been found in 11 queries.
# 26 has been found in 10 queries.
# 452 has been found in 10 queries.
# 1037 has been found in 10 queries.
# 100 has been found in 10 queries.
# 190 has been found in 9 queries.
# 92 has been found in 10 queries.
# 364 has been found in 10 queries.
# 1000 has been found in 11 queries.
# 988 has been found in 10 queries.
# 408 has been found in 9 queries.
# 866 has been found in 10 queries.
# 155 has been found in 9 queries.
# 980 has been found in 9 queries.
# 500 has been found in 8 queries.
# 118 has been found in 10 queries.
# 97 has been found in 10 queries.
# 558 has been found in 9 queries.
# 1275 has been found in 9 queries.
# 1089 has been found in 11 queries.
# 238 has been found in 10 queries.
# 1029 has been found in 8 queries.
# 716 has been found in 9 queries.
# 954 has been found in 10 queries.
# 11 has been found in 10 queries.
# 786 has been found in 10 queries.
# 596 has been found in 11 queries.
# 536 has been found in 7 queries.
# 1098 has been found in 10 queries.
# 1109 has been found in 10 queries.
# 501 has been found in 11 queries.
# 445 has been found in 10 queries.
# 210 has been found in 11 queries.
# 897 has been found in 9 queries.
# 199 has been found in 11 queries.
# 103 has been found in 10 queries.
# 930 has been found in 9 queries.
# 560 has been found in 11 queries.
# 621 has been found in 11 queries.
# 107 has been found in 9 queries.
# 1452 has been found in 5 queries.
# 969 has been found in 10 queries.
# 1023 has been found in 11 queries.
# 129 has been found in 10 queries.
# 202 has been found in 10 queries.
# 60 has been found in 9 queries.
# 638 has been found in 10 queries.
# 179 has been found in 10 queries.
# 486 has been found in 7 queries.
# 477 has been found in 9 queries.
# 679 has been found in 11 queries.
# 1099 has been found in 4 queries.
# 60 has been found in 11 queries.
# 37 has been found in 10 queries.
# 1452 has been found in 9 queries.
# 166 has been found in 11 queries.
# 890 has been found in 10 queries.
# 630 has been found in 8 queries.
# 1404 has been found in 10 queries.
# 517 has been found in 10 queries.
# 1273 has been found in 11 queries.
# 615 has been found in 8 queries.
# 264 has been found in 11 queries.
# 904 has been found in 11 queries.
# 1610 has been found in 11 queries.
# 639 has been found in 9 queries.
# 1221 has been found in 10 queries.
# 1549 has been found in 11 queries.
# 785 has been found in 11 queries.
# 115 has been found in 9 queries.
# 1435 has been found in 11 queries.
# 1591 has been found in 9 queries.
# 682 has been found in 10 queries.
# 590 has been found in 10 queries.
# 157 has been found in 9 queries.
# 148 has been found in 10 queries.
# 550 has been found in 9 queries.
# 906 has been found in 8 queries.
# 725 has been found in 7 queries.
# 217 has been found in 11 queries.
# 887 has been found in 10 queries.
# 1474 has been found in 11 queries.
# 1186 has been found in 3 queries.
# 200 has been found in 11 queries.
# 89 has been found in 10 queries.
# 456 has been found in 11 queries.
# 57 has been found in 10 queries.
# 1063 has been found in 9 queries.
# 780 has been found in 6 queries.
# 610 has been found in 10 queries.
# 1353 has been found in 11 queries.
# 1458 has been found in 11 queries.
# 22 has been found in 11 queries.
# 25 has been found in 10 queries.
# 1710 has been found in 11 queries.
# 146 has been found in 11 queries.
# 312 has been found in 10 queries.
# 1925 has been found in 11 queries.
# 153 has been found in 10 queries.
# 1674 has been found in 10 queries.
# 1603 has been found in 11 queries.
# 655 has been found in 4 queries.
# 1853 has been found in 11 queries.
# 338 has been found in 11 queries.
# 2092 has been found in 10 queries.
# 1558 has been found in 11 queries.
# 1510 has been found in 10 queries.
# 1580 has been found in 10 queries.
# 655 has been found in 9 queries.
# 1904 has been found in 11 queries.
# 914 has been found in 11 queries.
# 1545 has been found in 6 queries.
# 1449 has been found in 11 queries.
# 775 has been found in 11 queries.
# 1908 has been found in 10 queries.
# 2011 has been found in 10 queries.
# 392 has been found in 12 queries.
# 633 has been found in 12 queries.
# 2158 has been found in 11 queries.
# 1677 has been found in 11 queries.
# 1655 has been found in 11 queries.
# 1303 has been found in 10 queries.
# 1349 has been found in 11 queries.
# 1815 has been found in 10 queries.
# 1952 has been found in 9 queries.
# 1866 has been found in 12 queries.
# 864 has been found in 11 queries.
# 1329 has been found in 11 queries.
# 1587 has been found in 9 queries.
# 752 has been found in 11 queries.
# 2381 has been found in 11 queries.
# 392 has been found in 7 queries.
# 985 has been found in 10 queries.
# 2228 has been found in 11 queries.
# 2373 has been found in 11 queries.
# 24 has been found in 10 queries.
# 1605 has been found in 12 queries.
# 503 has been found in 11 queries.
# 2175 has been found in 12 queries.
# 1552 has been found in 11 queries.
# 2012 has been found in 10 queries.
# 1611 has been found in 10 queries.
# 896 has been found in 12 queries.
# 324 has been found in 11 queries.
# 964 has been found in 12 queries.
# 1932 has been found in 7 queries.
# 2012 has been found in 10 queries.
# 896 has been found in 12 queries.
# 2392 has been found in 10 queries.
# 413 has been found in 11 queries.
# 1650 has been found in 11 queries.
# 621 has been found in 11 queries.
# 817 has been found in 11 queries.
# 718 has been found in 12 queries.
# 2484 has been found in 11 queries.
# 1546 has been found in 12 queries.
# 2576 has been found in 11 queries.
# 1091 has been found in 11 queries.
# 267 has been found in 9 queries.
# 947 has been found in 7 queries.
# 1724 has been found in 12 queries.
# 245 has been found in 12 queries.
# 711 has been found in 11 queries.
# 180 has been found in 10 queries.
# 8 has been found in 11 queries.
# 1138 has been found in 11 queries.
# 1572 has been found in 11 queries.
# 1885 has been found in 12 queries.
# 2786 has been found in 11 queries.
# 1544 has been found in 11 queries.
# 1290 has been found in 11 queries.
# 2599 has been found in 10 queries.
# 2630 has been found in 11 queries.
# 2123 has been found in 11 queries.
# 1828 has been found in 11 queries.
# 1372 has been found in 11 queries.
# 1133 has been found in 10 queries.
# 476 has been found in 12 queries.
# 72 has been found in 9 queries.
# 487 has been found in 12 queries.
# 1770 has been found in 9 queries.
# 2181 has been found in 12 queries.
# 1188 has been found in 11 queries.
# 274 has been found in 11 queries.
# 2861 has been found in 10 queries.
# 1230 has been found in 11 queries.
# 159 has been found in 11 queries.
# 2329 has been found in 10 queries.
# 2907 has been found in 10 queries.
# 1 has been found in 11 queries.
# 915 has been found in 10 queries.
# 2120 has been found in 11 queries.
# 1230 has been found in 12 queries.
# 1285 has been found in 11 queries.
# 816 has been found in 11 queries.
# 2164 has been found in 11 queries.
# 2038 has been found in 11 queries.
# 647 has been found in 11 queries.
# 1331 has been found in 11 queries.
# 111 has been found in 10 queries.
# 50 has been found in 12 queries.
# 2585 has been found in 12 queries.
# 521 has been found in 12 queries.
# 2924 has been found in 11 queries.
# 1320 has been found in 12 queries.
# 1230 has been found in 10 queries.
# 146 has been found in 12 queries.
# 844 has been found in 11 queries.
# 2281 has been found in 11 queries.
# 1344 has been found in 12 queries.
# 1015 has been found in 11 queries.
# 1120 has been found in 10 queries.
# 2724 has been found in 7 queries.
# 2757 has been found in 12 queries.
# 2885 has been found in 12 queries.
# 2611 has been found in 8 queries.
# 986 has been found in 8 queries.
# 833 has been found in 10 queries.
# 1510 has been found in 11 queries.
# 29 has been found in 11 queries.
# 523 has been found in 12 queries.
# 38 has been found in 8 queries.
# 1569 has been found in 11 queries.
# 2763 has been found in 9 queries.
# 2060 has been found in 12 queries.
# 787 has been found in 12 queries.
# 931 has been found in 11 queries.
# 1540 has been found in 12 queries.
# 1234 has been found in 11 queries.
# 2005 has been found in 12 queries.
# 578 has been found in 12 queries.
# 2860 has been found in 9 queries.
# 2337 has been found in 11 queries.
# 1211 has been found in 11 queries.
# 1313 has been found in 8 queries.
# 3383 has been found in 11 queries.
# 2444 has been found in 12 queries.
# 2665 has been found in 12 queries.
# 1801 has been found in 11 queries.
# 843 has been found in 12 queries.
# 2686 has been found in 12 queries.
# 2551 has been found in 10 queries.
# 944 has been found in 10 queries.
# 446 has been found in 10 queries.
# 2062 has been found in 8 queries.
# 1742 has been found in 9 queries.
# 1000 has been found in 12 queries.
# 120 has been found in 11 queries.
# 3375 has been found in 11 queries.
# 2784 has been found in 11 queries.
# 440 has been found in 12 queries.
# 2766 has been found in 12 queries.
# 1230 has been found in 11 queries.
# 1009 has been found in 11 queries.
# 1578 has been found in 12 queries.
# 1789 has been found in 11 queries.
# 2723 has been found in 10 queries.
# 1766 has been found in 10 queries.
# 1639 has been found in 12 queries.
# 1690 has been found in 11 queries.
# 830 has been found in 12 queries.
# 3286 has been found in 12 queries.
# 863 has been found in 12 queries.
# 2493 has been found in 12 queries.
# 2425 has been found in 12 queries.
# 631 has been found in 10 queries.
# 2772 has been found in 11 queries.
# 2246 has been found in 12 queries.
# 543 has been found in 10 queries.
# 2174 has been found in 11 queries.
# 3366 has been found in 11 queries.
# 2432 has been found in 12 queries.
# 3365 has been found in 12 queries.
# 2201 has been found in 12 queries.
# 2694 has been found in 11 queries.
# 2114 has been found in 12 queries.
# 2993 has been found in 12 queries.
# 2078 has been found in 12 queries.
# 3217 has been found in 12 queries.
# 296 has been found in 9 queries.
# 415 has been found in 12 queries.
# 3551 has been found in 10 queries.
# 2667 has been found in 12 queries.
# 2401 has been found in 10 queries.
# 345 has been found in 10 queries.
# 2602 has been found in 12 queries.
# 237 has been found in 11 queries.
# 1016 has been found in 12 queries.
# 3747 has been found in 11 queries.
# 3015 has been found in 12 queries.
# 1522 has been found in 9 queries.
# 1068 has been found in 9 queries.
# 1971 has been found in 10 queries.
# 1193 has been found in 9 queries.
# 660 has been found in 11 queries.
# 484 has been found in 12 queries.
# 1725 has been found in 9 queries.
# 2412 has been found in 9 queries.
# 905 has been found in 12 queries.
# 1572 has been found in 10 queries.
# 356 has been found in 10 queries.
# 3241 has been found in 12 queries.
# 1095 has been found in 12 queries.
# 325 has been found in 12 queries.
# 3456 has been found in 11 queries.
# 3004 has been found in 12 queries.
# 2450 has been found in 12 queries.
# 78 has been found in 11 queries.
# 4045 has been found in 12 queries.
# 261 has been found in 13 queries.
# 3914 has been found in 12 queries.
# 1644 has been found in 12 queries.
# 2030 has been found in 11 queries.
# 2240 has been found in 11 queries.
# 4112 has been found in 10 queries.
# 2154 has been found in 12 queries.
# 3927 has been found in 9 queries.
# 1928 has been found in 12 queries.
# 2349 has been found in 13 queries.
# 3567 has been found in 9 queries.
# 1936 has been found in 11 queries.
# 2598 has been found in 11 queries.
# 2352 has been found in 11 queries.
# 2420 has been found in 12 queries.
# 1433 has been found in 9 queries.
# 3520 has been found in 10 queries.
# 2048 has been found in 12 queries.
# 3611 has been found in 11 queries.
# 98 has been found in 12 queries.
# 684 has been found in 12 queries.
# 823 has been found in 13 queries.
# 3434 has been found in 12 queries.
# 3819 has been found in 12 queries.
# 1479 has been found in 12 queries.
# 1207 has been found in 11 queries.
# 3475 has been found in 12 queries.
# 3000 has been found in 12 queries.
# 415 has been found in 10 queries.
# 805 has been found in 12 queries.
# 3573 has been found in 12 queries.
# 1521 has been found in 12 queries.
# 1966 has been found in 13 queries.
# 4342 has been found in 11 queries.
# 4403 has been found in 11 queries.
# 3832 has been found in 11 queries.
# 839 has been found in 12 queries.
# 2169 has been found in 9 queries.
# 2240 has been found in 9 queries.
# 4404 has been found in 12 queries.
# 11 has been found in 12 queries.
# 2142 has been found in 12 queries.
# 3763 has been found in 9 queries.
# 4235 has been found in 12 queries.
# 2617 has been found in 10 queries.
# 544 has been found in 11 queries.
# 1270 has been found in 12 queries.
# 3390 has been found in 10 queries.
# 3781 has been found in 9 queries.
# 1064 has been found in 12 queries.
# 3887 has been found in 11 queries.
# 3245 has been found in 11 queries.
# 2359 has been found in 12 queries.
# 3054 has been found in 13 queries.
# 2982 has been found in 12 queries.
# 3987 has been found in 12 queries.
# 4391 has been found in 12 queries.
# 3734 has been found in 12 queries.
# 4096 has been found in 10 queries.
# 4760 has been found in 13 queries.
# 4285 has been found in 11 queries.
# 3947 has been found in 11 queries.
# 3577 has been found in 11 queries.
# 1440 has been found in 12 queries.
# 2981 has been found in 12 queries.
# 1701 has been found in 12 queries.
# 4029 has been found in 13 queries.
# 2194 has been found in 11 queries.
# 3079 has been found in 12 queries.
# 1601 has been found in 10 queries.
# 4393 has been found in 12 queries.
# 4117 has been found in 13 queries.
# 1365 has been found in 12 queries.
# 4490 has been found in 13 queries.
# 823 has been found in 12 queries.
# 4709 has been found in 12 queries.
# 365 has been found in 11 queries.
# 4576 has been found in 13 queries.
# 1212 has been found in 12 queries.
# 365 has been found in 10 queries.
# 3452 has been found in 11 queries.
# 4018 has been found in 12 queries.
# 1769 has been found in 13 queries.
# 3675 has been found in 12 queries.
# 1352 has been found in 12 queries.
# 2914 has been found in 12 queries.
# 4854 has been found in 12 queries.
# 1296 has been found in 13 queries.
# 2539 has been found in 12 queries.
# 1197 has been found in 12 queries.
# 3307 has been found in 11 queries.
# 3738 has been found in 13 queries.
# 4606 has been found in 12 queries.
# 831 has been found in 12 queries.
# 2070 has been found in 5 queries.
# 1537 has been found in 10 queries.
# 1246 has been found in 11 queries.
# 2113 has been found in 12 queries.
# 4425 has been found in 13 queries.
# 4138 has been found in 13 queries.
# 836 has been found in 10 queries.
# 959 has been found in 12 queries.
# 647 has been found in 12 queries.
# 1734 has been found in 13 queries.
# 2140 has been found in 13 queries.
# 2821 has been found in 8 queries.
# 4197 has been found in 13 queries.
# 5007 has been found in 11 queries.
# 748 has been found in 12 queries.
# 2407 has been found in 11 queries.
# 1059 has been found in 10 queries.
# 4813 has been found in 11 queries.
# 3129 has been found in 10 queries.
# 736 has been found in 12 queries.
# 3063 has been found in 12 queries.
# 4825 has been found in 13 queries.
# 23 has been found in 12 queries.
# 2814 has been found in 5 queries.
# 3498 has been found in 11 queries.
# 5327 has been found in 12 queries.
# 3182 has been found in 13 queries.
# 1468 has been found in 13 queries.
# 3793 has been found in 12 queries.
# 4410 has been found in 12 queries.
# 4779 has been found in 12 queries.
# 2080 has been found in 13 queries.
# 3380 has been found in 12 queries.
# 70 has been found in 11 queries.
# 1747 has been found in 12 queries.
# 1649 has been found in 11 queries.
# 4512 has been found in 11 queries.
# 2864 has been found in 12 queries.
# 727 has been found in 12 queries.
# 1110 has been found in 10 queries.
# 3535 has been found in 12 queries.
# 2261 has been found in 13 queries.
# 5310 has been found in 10 queries.
# 4605 has been found in 13 queries.
# 2318 has been found in 13 queries.
# 4823 has been found in 12 queries.
# 4222 has been found in 11 queries.
# 2351 has been found in 12 queries.
# 5126 has been found in 12 queries.
# 1532 has been found in 11 queries.
# 2500 has been found in 11 queries.
# 741 has been found in 13 queries.
# 1989 has been found in 8 queries.
# 914 has been found in 11 queries.
# 418 has been found in 13 queries.
# 2653 has been found in 12 queries.
# 2218 has been found in 13 queries.
# 704 has been found in 12 queries.
# 208 has been found in 11 queries.
# 3979 has been found in 13 queries.
# 5477 has been found in 11 queries.
# 4677 has been found in 12 queries.
# 1624 has been found in 8 queries.
# 3167 has been found in 13 queries.
# 4996 has been found in 13 queries.
# 3273 has been found in 12 queries.
# 3073 has been found in 13 queries.
# 4042 has been found in 9 queries.
# 821 has been found in 13 queries.
# 342 has been found in 12 queries.
# 1472 has been found in 12 queries.
# 803 has been found in 12 queries.
# 1353 has been found in 12 queries.
# 3109 has been found in 13 queries.
# 5346 has been found in 12 queries.
# 266 has been found in 13 queries.
# 5236 has been found in 12 queries.
# 240 has been found in 13 queries.
# 2777 has been found in 13 queries.
# 1434 has been found in 13 queries.
# 4299 has been found in 11 queries.
# 1989 has been found in 12 queries.
# 1795 has been found in 13 queries.
# 200 has been found in 13 queries.
# 2944 has been found in 12 queries.
# 5591 has been found in 11 queries.
# 1536 has been found in 11 queries.
# 2432 has been found in 13 queries.
# 1916 has been found in 13 queries.
# 2417 has been found in 13 queries.
# 1182 has been found in 12 queries.
# 2347 has been found in 10 queries.
# 480 has been found in 13 queries.
# 4672 has been found in 12 queries.
# 4531 has been found in 12 queries.
# 250 has been found in 12 queries.
# 5844 has been found in 13 queries.
# 2774 has been found in 9 queries.
# 2551 has been found in 12 queries.
# 189 has been found in 13 queries.
# 748 has been found in 12 queries.
# 985 has been found in 12 queries.
# 3225 has been found in 12 queries.
# 5339 has been found in 12 queries.
# 813 has been found in 12 queries.
# 2848 has been found in 12 queries.
# 3377 has been found in 12 queries.
# 3589 has been found in 10 queries.
# 4004 has been found in 12 queries.
# 1734 has been found in 13 queries.
# 2019 has been found in 13 queries.
# 4958 has been found in 12 queries.
# 209 has been found in 12 queries.
# 2643 has been found in 13 queries.
# 3025 has been found in 13 queries.
# 2536 has been found in 11 queries.
# 6099 has been found in 13 queries.
# 4180 has been found in 12 queries.
# 5092 has been found in 8 queries.
# 949 has been found in 11 queries.
# 4238 has been found in 12 queries.
# 951 has been found in 13 queries.
# 4741 has been found in 13 queries.
# 2298 has been found in 9 queries.
# 3903 has been found in 13 queries.
# 4667 has been found in 10 queries.
# 5748 has been found in 13 queries.
# 5181 has been found in 12 queries.
# 3966 has been found in 13 queries.
# 5664 has been found in 11 queries.
# 1341 has been found in 13 queries.
# 5869 has been found in 13 queries.
# 1179 has been found in 13 queries.
# 319 has been found in 13 queries.
# 863 has been found in 13 queries.
# 6352 has been found in 10 queries.
# 548 has been found in 11 queries.
# 5104 has been found in 13 queries.
# 729 has been found in 12 queries.
# 3450 has been found in 12 queries.
# 2102 has been found in 13 queries.
# 665 has been found in 10 queries.
# 1478 has been found in 12 queries.
# 697 has been found in 9 queries.
# 4555 has been found in 9 queries.
# 1333 has been found in 12 queries.
# 2212 has been found in 13 queries.
# 3821 has been found in 12 queries.
# 1111 has been found in 12 queries.
# 2334 has been found in 11 queries.
# 5552 has been found in 12 queries.
# 3907 has been found in 11 queries.
# 1409 has been found in 10 queries.
# 109 has been found in 10 queries.
# 6149 has been found in 13 queries.
# 5565 has been found in 10 queries.
# 174 has been found in 13 queries.
# 2651 has been found in 13 queries.
# 1022 has been found in 11 queries.
# 6653 has been found in 12 queries.
# 2713 has been found in 10 queries.
# 379 has been found in 12 queries.
# 1511 has been found in 13 queries.
# 661 has been found in 13 queries.
# 1259 has been found in 12 queries.
# 6336 has been found in 11 queries.
# 2411 has been found in 11 queries.
# 3394 has been found in 13 queries.
# 4240 has been found in 12 queries.
# 5008 has been found in 11 queries.
# 5654 has been found in 12 queries.
# 708 has been found in 10 queries.
# 2688 has been found in 12 queries.
# 4139 has been found in 13 queries.
# 4433 has been found in 13 queries.
# 1525 has been found in 13 queries.
# 2555 has been found in 11 queries.
# 2021 has been found in 12 queries.
# 1184 has been found in 13 queries.
# 1664 has been found in 12 queries.
# 2966 has been found in 11 queries.
# 3484 has been found in 11 queries.
# 6696 has been found in 9 queries.
# 3585 has been found in 13 queries.
# 5336 has been found in 12 queries.
# 6245 has been found in 13 queries.
# 3215 has been found in 13 queries.
# 3449 has been found in 13 queries.
# 1161 has been found in 13 queries.
# 4785 has been found in 13 queries.
# 6158 has been found in 12 queries.
# 5000 has been found in 12 queries.
# 3670 has been found in 13 queries.
# 3614 has been found in 10 queries.
# 2511 has been found in 13 queries.
# 6036 has been found in 13 queries.
# 4434 has been found in 12 queries.
# 4718 has been found in 12 queries.
# 5082 has been found in 12 queries.
# 1045 has been found in 10 queries.
# 2134 has been found in 12 queries.
# 1584 has been found in 12 queries.
# 5220 has been found in 12 queries.
# 4371 has been found in 12 queries.
# 3224 has been found in 13 queries.
# 6436 has been found in 13 queries.
# 2921 has been found in 13 queries.
# 3914 has been found in 13 queries.
# 5287 has been found in 12 queries.
# 3791 has been found in 11 queries.
# 1591 has been found in 11 queries.
# 1558 has been found in 13 queries.
# 3817 has been found in 13 queries.
# 6607 has been found in 13 queries.
# 6884 has been found in 13 queries.
# 3160 has been found in 13 queries.
# 577 has been found in 10 queries.
# 2800 has been found in 10 queries.
# 5196 has been found in 12 queries.
# 6115 has been found in 9 queries.
# 437 has been found in 11 queries.
# 890 has been found in 10 queries.
# 4679 has been found in 13 queries.
# 4683 has been found in 12 queries.
# 937 has been found in 13 queries.
# 4323 has been found in 13 queries.
# 2824 has been found in 13 queries.
# 2290 has been found in 12 queries.
# 6660 has been found in 13 queries.
# 3912 has been found in 13 queries.
# 939 has been found in 12 queries.
# 4681 has been found in 7 queries.
# 3211 has been found in 13 queries.
# 5909 has been found in 9 queries.
# 2029 has been found in 10 queries.
# 7228 has been found in 12 queries.
# 3072 has been found in 12 queries.
# 803 has been found in 13 queries.
# 3479 has been found in 13 queries.
# 1228 has been found in 13 queries.
# 4424 has been found in 11 queries.
# 6141 has been found in 13 queries.
# 6752 has been found in 13 queries.
# 1923 has been found in 13 queries.
# 2538 has been found in 10 queries.
# 3180 has been found in 12 queries.
# 4615 has been found in 9 queries.
# 7448 has been found in 12 queries.
# 131 has been found in 13 queries.
# 669 has been found in 11 queries.
# 2067 has been found in 13 queries.
# 406 has been found in 10 queries.
# 7575 has been found in 13 queries.
# 186 has been found in 12 queries.
# 934 has been found in 9 queries.
# 6332 has been found in 13 queries.
# 134 has been found in 13 queries.
# 3567 has been found in 12 queries.
# 4081 has been found in 10 queries.
# 4930 has been found in 13 queries.
# 6806 has been found in 13 queries.
# 7378 has been found in 11 queries.
# 3732 has been found in 13 queries.
# 2415 has been found in 13 queries.
# 5226 has been found in 13 queries.
# 839 has been found in 13 queries.
# 7248 has been found in 12 queries.
# 2616 has been found in 13 queries.
# 5119 has been found in 13 queries.
# 3184 has been found in 13 queries.
# 6429 has been found in 13 queries.
# 7434 has been found in 12 queries.
# 5407 has been found in 13 queries.
# 5977 has been found in 10 queries.
# 4163 has been found in 13 queries.
# 3974 has been found in 13 queries.
# 5026 has been found in 12 queries.
# 340 has been found in 13 queries.
# 4026 has been found in 13 queries.
# 5080 has been found in 12 queries.
# 169 has been found in 13 queries.
# 5237 has been found in 13 queries.
# 2905 has been found in 13 queries.
# 7453 has been found in 13 queries.
# 5031 has been found in 11 queries.
# 5842 has been found in 8 queries.
# 3523 has been found in 13 queries.
# 1864 has been found in 12 queries.
# 5455 has been found in 11 queries.
# 3195 has been found in 12 queries.
# 3116 has been found in 10 queries.
# 1643 has been found in 11 queries.
# 1314 has been found in 11 queries.
# 6372 has been found in 12 queries.
# 5127 has been found in 11 queries.
# 6931 has been found in 11 queries.
# 1405 has been found in 13 queries.
# 1466 has been found in 11 queries.
# 1034 has been found in 13 queries.
# 1893 has been found in 11 queries.
# 4956 has been found in 13 queries.
# 6449 has been found in 11 queries.
# 457 has been found in 13 queries.
# 723 has been found in 11 queries.
# 6238 has been found in 13 queries.
# 7720 has been found in 12 queries.
# 6262 has been found in 13 queries.
# 3731 has been found in 13 queries.
# 4448 has been found in 13 queries.
# 4554 has been found in 13 queries.
# 6290 has been found in 13 queries.
# 4423 has been found in 11 queries.
# 4911 has been found in 11 queries.
# 6328 has been found in 13 queries.
# 7181 has been found in 13 queries.
# 6319 has been found in 13 queries.
# 7255 has been found in 13 queries.
# 360 has been found in 13 queries.
# 5427 has been found in 13 queries.
# 1411 has been found in 13 queries.
# 4267 has been found in 12 queries.
# 806 has been found in 13 queries.
# 4569 has been found in 8 queries.
# 3590 has been found in 13 queries.
# 2057 has been found in 9 queries.
# 3537 has been found in 11 queries.
# 5527 has been found in 9 queries.
# 5214 has been found in 13 queries.
# 6070 has been found in 12 queries.
# 6388 has been found in 10 queries.
# 1833 has been found in 12 queries.
# 4666 has been found in 10 queries.
# 2904 has been found in 12 queries.
# 4408 has been found in 13 queries.
# 6225 has been found in 13 queries.
# 2415 has been found in 12 queries.
# 6093 has been found in 12 queries.
# 4411 has been found in 12 queries.
# 4802 has been found in 12 queries.
# 6525 has been found in 13 queries.
# 2475 has been found in 11 queries.
# 239 has been found in 10 queries.
# 6815 has been found in 12 queries.
# 4385 has been found in 11 queries.
# 3159 has been found in 13 queries.
# 8085 has been found in 10 queries.
# 5704 has been found in 11 queries.
# 1001 has been found in 11 queries.
# 69 has been found in 12 queries.
# 6447 has been found in 13 queries.
# 3370 has been found in 11 queries.
# 3559 has been found in 7 queries.
# 1371 has been found in 13 queries.
# 4307 has been found in 10 queries.
# 1379 has been found in 11 queries.
# 3575 has been found in 10 queries.
# 3224 has been found in 12 queries.
# 641 has been found in 13 queries.
# 1051 has been found in 13 queries.
# 4974 has been found in 12 queries.
# 6883 has been found in 13 queries.
# 1397 has been found in 13 queries.
# 4732 has been found in 12 queries.
# 911 has been found in 13 queries.
# 4101 has been found in 13 queries.
# 7852 has been found in 14 queries.
# 8139 has been found in 13 queries.
# 1103 has been found in 11 queries.
# 3209 has been found in 12 queries.
# 1304 has been found in 14 queries.
# 7074 has been found in 13 queries.
# 2059 has been found in 13 queries.
# 6001 has been found in 11 queries.
# 342 has been found in 7 queries.
# 1767 has been found in 14 queries.
# 112 has been found in 10 queries.
# 1879 has been found in 13 queries.
# 653 has been found in 12 queries.
# 7352 has been found in 13 queries.
# 2181 has been found in 13 queries.
# 2209 has been found in 13 queries.
# 6520 has been found in 11 queries.
# 5454 has been found in 13 queries.
# 2723 has been found in 13 queries.
# 1438 has been found in 12 queries.
# 7606 has been found in 12 queries.
# 2108 has been found in 6 queries.
# 4898 has been found in 13 queries.
# 5601 has been found in 11 queries.
# 4426 has been found in 13 queries.
# 529 has been found in 13 queries.
# 692 has been found in 14 queries.
# 802 has been found in 11 queries.
# 4811 has been found in 13 queries.
# 4543 has been found in 13 queries.
# 2168 has been found in 12 queries.
# 4747 has been found in 13 queries.
# 4354 has been found in 12 queries.
# 1833 has been found in 11 queries.
# 5423 has been found in 13 queries.
# 2946 has been found in 13 queries.
# 5440 has been found in 11 queries.
# 8359 has been found in 14 queries.
# 6528 has been found in 13 queries.
# 8307 has been found in 10 queries.
# 4564 has been found in 13 queries.
# 3138 has been found in 11 queries.
# 995 has been found in 14 queries.
# 2136 has been found in 14 queries.
# 5242 has been found in 12 queries.
# 1927 has been found in 12 queries.
# 2853 has been found in 12 queries.
# 1461 has been found in 13 queries.
# 3226 has been found in 12 queries.
# 5706 has been found in 12 queries.
# 4419 has been found in 13 queries.
# 7337 has been found in 13 queries.
# 7322 has been found in 11 queries.
# 8087 has been found in 12 queries.
# 8529 has been found in 11 queries.
# 3987 has been found in 13 queries.
# 2399 has been found in 13 queries.
# 5239 has been found in 10 queries.
# 6316 has been found in 12 queries.
# 3513 has been found in 10 queries.
# 6806 has been found in 12 queries.
# 3908 has been found in 9 queries.
# 229 has been found in 13 queries.
# 4118 has been found in 13 queries.
# 7753 has been found in 13 queries.
# 3155 has been found in 14 queries.
# 5100 has been found in 13 queries.
# 3536 has been found in 13 queries.
# 2651 has been found in 10 queries.
# 2292 has been found in 14 queries.
# 2286 has been found in 12 queries.
# 7278 has been found in 12 queries.
# 5374 has been found in 11 queries.
# 8727 has been found in 14 queries.
# 5506 has been found in 13 queries.
# 7622 has been found in 14 queries.
# 6850 has been found in 13 queries.
# 7092 has been found in 12 queries.
# 2611 has been found in 12 queries.
# 7762 has been found in 14 queries.
# 3312 has been found in 11 queries.
# 6370 has been found in 13 queries.
# 5876 has been found in 10 queries.
# 17 has been found in 14 queries.
# 4844 has been found in 14 queries.
# 8855 has been found in 12 queries.
# 1327 has been found in 12 queries.
# 6382 has been found in 14 queries.
# 2323 has been found in 14 queries.
# 1665 has been found in 13 queries.
# 1595 has been found in 13 queries.
# 3160 has been found in 13 queries.
# 4857 has been found in 14 queries.
# 1473 has been found in 13 queries.
# 126 has been found in 14 queries.
# 7129 has been found in 13 queries.
# 8606 has been found in 13 queries.
# 4242 has been found in 4 queries.
# 9510 has been found in 13 queries.
# 7717 has been found in 14 queries.
# 2672 has been found in 14 queries.
# 8112 has been found in 13 queries.
# 2531 has been found in 12 queries.
# 2584 has been found in 12 queries.
# 8323 has been found in 14 queries.
# 3609 has been found in 13 queries.
# 3406 has been found in 13 queries.
# 422 has been found in 12 queries.
# 4690 has been found in 13 queries.
# 3344 has been found in 12 queries.
# 3340 has been found in 13 queries.
# 9403 has been found in 14 queries.
# 6348 has been found in 14 queries.
# 4495 has been found in 12 queries.
# 7598 has been found in 13 queries.
# 2028 has been found in 9 queries.
# 1527 has been found in 13 queries.
# 7774 has been found in 13 queries.
# 7640 has been found in 11 queries.
# 2778 has been found in 11 queries.
# []

# %% [markdown]
# #### **Problem #2.5**
#
# **Together**, let's graph the worst number of queries for list sizes from 100 to 10000 *for both linear and binary search*.

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]
  binary_queries += [binary_search(n)]

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# 96 has been found in 7 queries.
# 53 has been found in 6 queries.
# 72 has been found in 6 queries.
# 81 has been found in 6 queries.
# 89 has been found in 5 queries.
# 80 has been found in 4 queries.
# 87 has been found in 6 queries.
# 19 has been found in 6 queries.
# 34 has been found in 6 queries.
# 63 has been found in 7 queries.
# 70 has been found in 6 queries.
# 136 has been found in 4 queries.
# 11 has been found in 8 queries.
# 186 has been found in 4 queries.
# 72 has been found in 7 queries.
# 110 has been found in 8 queries.
# 75 has been found in 7 queries.
# 95 has been found in 6 queries.
# 37 has been found in 7 queries.
# 67 has been found in 5 queries.
# 149 has been found in 1 queries.
# 286 has been found in 7 queries.
# 184 has been found in 8 queries.
# 9 has been found in 5 queries.
# 11 has been found in 7 queries.
# 278 has been found in 8 queries.
# 74 has been found in 2 queries.
# 271 has been found in 8 queries.
# 289 has been found in 5 queries.
# 44 has been found in 8 queries.
# 310 has been found in 9 queries.
# 276 has been found in 9 queries.
# 32 has been found in 9 queries.
# 122 has been found in 8 queries.
# 347 has been found in 8 queries.
# 386 has been found in 5 queries.
# 172 has been found in 8 queries.
# 89 has been found in 7 queries.
# 387 has been found in 8 queries.
# 103 has been found in 8 queries.
# 234 has been found in 9 queries.
# 161 has been found in 9 queries.
# 231 has been found in 8 queries.
# 247 has been found in 8 queries.
# 303 has been found in 6 queries.
# 166 has been found in 7 queries.
# 156 has been found in 8 queries.
# 438 has been found in 9 queries.
# 79 has been found in 8 queries.
# 253 has been found in 9 queries.
# 337 has been found in 9 queries.
# 532 has been found in 10 queries.
# 41 has been found in 7 queries.
# 309 has been found in 9 queries.
# 509 has been found in 7 queries.
# 192 has been found in 8 queries.
# 501 has been found in 9 queries.
# 458 has been found in 6 queries.
# 265 has been found in 7 queries.
# 330 has been found in 10 queries.
# 531 has been found in 8 queries.
# 71 has been found in 9 queries.
# 34 has been found in 8 queries.
# 291 has been found in 8 queries.
# 612 has been found in 9 queries.
# 466 has been found in 8 queries.
# 444 has been found in 8 queries.
# 96 has been found in 10 queries.
# 39 has been found in 10 queries.
# 266 has been found in 7 queries.
# 520 has been found in 8 queries.
# 175 has been found in 9 queries.
# 609 has been found in 9 queries.
# 10 has been found in 9 queries.
# 198 has been found in 10 queries.
# 249 has been found in 4 queries.
# 728 has been found in 9 queries.
# 108 has been found in 8 queries.
# 283 has been found in 8 queries.
# 2 has been found in 10 queries.
# 624 has been found in 7 queries.
# 862 has been found in 10 queries.
# 291 has been found in 10 queries.
# 737 has been found in 7 queries.
# 184 has been found in 10 queries.
# 229 has been found in 9 queries.
# 260 has been found in 9 queries.
# 516 has been found in 10 queries.
# 397 has been found in 9 queries.
# 887 has been found in 8 queries.
# 50 has been found in 8 queries.
# 619 has been found in 10 queries.
# 668 has been found in 9 queries.
# 879 has been found in 9 queries.
# 814 has been found in 8 queries.
# 482 has been found in 10 queries.
# 777 has been found in 10 queries.
# 575 has been found in 10 queries.
# 741 has been found in 7 queries.
# 536 has been found in 10 queries.
# 81 has been found in 10 queries.
# 155 has been found in 10 queries.
# 1062 has been found in 10 queries.
# 58 has been found in 10 queries.
# 716 has been found in 10 queries.
# 235 has been found in 10 queries.
# 710 has been found in 10 queries.
# 15 has been found in 10 queries.
# 688 has been found in 9 queries.
# 992 has been found in 9 queries.
# 912 has been found in 8 queries.
# 203 has been found in 10 queries.
# 1065 has been found in 10 queries.
# 420 has been found in 7 queries.
# 354 has been found in 11 queries.
# 187 has been found in 10 queries.
# 454 has been found in 10 queries.
# 450 has been found in 10 queries.
# 840 has been found in 10 queries.
# 1160 has been found in 11 queries.
# 1112 has been found in 9 queries.
# 821 has been found in 7 queries.
# 354 has been found in 7 queries.
# 692 has been found in 10 queries.
# 705 has been found in 10 queries.
# 840 has been found in 11 queries.
# 229 has been found in 9 queries.
# 22 has been found in 9 queries.
# 850 has been found in 11 queries.
# 661 has been found in 9 queries.
# 218 has been found in 10 queries.
# 872 has been found in 10 queries.
# 1128 has been found in 10 queries.
# 95 has been found in 10 queries.
# 338 has been found in 7 queries.
# 349 has been found in 2 queries.
# 70 has been found in 8 queries.
# 136 has been found in 10 queries.
# 585 has been found in 11 queries.
# 201 has been found in 10 queries.
# 804 has been found in 10 queries.
# 1322 has been found in 7 queries.
# 195 has been found in 9 queries.
# 1019 has been found in 10 queries.
# 872 has been found in 10 queries.
# 255 has been found in 11 queries.
# 488 has been found in 10 queries.
# 1010 has been found in 10 queries.
# 863 has been found in 10 queries.
# 341 has been found in 9 queries.
# 923 has been found in 11 queries.
# 1192 has been found in 8 queries.
# 207 has been found in 11 queries.
# 1063 has been found in 11 queries.
# 1151 has been found in 11 queries.
# 38 has been found in 11 queries.
# 1169 has been found in 11 queries.
# 100 has been found in 10 queries.
# 1166 has been found in 11 queries.
# 1192 has been found in 8 queries.
# 168 has been found in 9 queries.
# 533 has been found in 9 queries.
# 715 has been found in 6 queries.
# 1450 has been found in 10 queries.
# 167 has been found in 11 queries.
# 430 has been found in 8 queries.
# 712 has been found in 11 queries.
# 667 has been found in 11 queries.
# 1054 has been found in 8 queries.
# 999 has been found in 10 queries.
# 102 has been found in 11 queries.
# 1326 has been found in 11 queries.
# 954 has been found in 11 queries.
# 443 has been found in 10 queries.
# 1532 has been found in 10 queries.
# 949 has been found in 10 queries.
# 767 has been found in 11 queries.
# 1204 has been found in 9 queries.
# 983 has been found in 6 queries.
# 1026 has been found in 10 queries.
# 906 has been found in 11 queries.
# 1378 has been found in 11 queries.
# 1520 has been found in 11 queries.
# 236 has been found in 11 queries.
# 1622 has been found in 11 queries.
# 1030 has been found in 11 queries.
# 1232 has been found in 11 queries.
# 1857 has been found in 9 queries.
# 1371 has been found in 8 queries.
# 1877 has been found in 11 queries.
# 1105 has been found in 11 queries.
# 1434 has been found in 10 queries.
# 704 has been found in 11 queries.
# 259 has been found in 11 queries.
# 518 has been found in 9 queries.
# 428 has been found in 8 queries.
# 84 has been found in 11 queries.
# 1862 has been found in 9 queries.
# 777 has been found in 11 queries.
# 1622 has been found in 10 queries.
# 53 has been found in 11 queries.
# 274 has been found in 9 queries.
# 1857 has been found in 11 queries.
# 1419 has been found in 10 queries.
# 1250 has been found in 11 queries.
# 1756 has been found in 11 queries.
# 1082 has been found in 11 queries.
# 1057 has been found in 8 queries.
# 734 has been found in 10 queries.
# 1758 has been found in 11 queries.
# 1218 has been found in 7 queries.
# 331 has been found in 10 queries.
# 231 has been found in 11 queries.
# 981 has been found in 11 queries.
# 527 has been found in 11 queries.
# 1686 has been found in 11 queries.
# 309 has been found in 11 queries.
# 1730 has been found in 11 queries.
# 426 has been found in 11 queries.
# 1611 has been found in 10 queries.
# 1163 has been found in 10 queries.
# 568 has been found in 11 queries.
# 1471 has been found in 12 queries.
# 304 has been found in 7 queries.
# 1681 has been found in 10 queries.
# 892 has been found in 9 queries.
# 1773 has been found in 11 queries.
# 352 has been found in 11 queries.
# 876 has been found in 10 queries.
# 1802 has been found in 11 queries.
# 1006 has been found in 9 queries.
# 234 has been found in 11 queries.
# 333 has been found in 10 queries.
# 1341 has been found in 10 queries.
# 436 has been found in 10 queries.
# 537 has been found in 9 queries.
# 1704 has been found in 12 queries.
# 1337 has been found in 11 queries.
# 1490 has been found in 11 queries.
# 769 has been found in 10 queries.
# 2294 has been found in 11 queries.
# 2247 has been found in 11 queries.
# 955 has been found in 7 queries.
# 1923 has been found in 11 queries.
# 1776 has been found in 11 queries.
# 388 has been found in 11 queries.
# 22 has been found in 11 queries.
# 2295 has been found in 10 queries.
# 1828 has been found in 12 queries.
# 2008 has been found in 11 queries.
# 1366 has been found in 10 queries.
# 2208 has been found in 11 queries.
# 2060 has been found in 8 queries.
# 532 has been found in 11 queries.
# 2267 has been found in 12 queries.
# 1635 has been found in 11 queries.
# 1213 has been found in 12 queries.
# 1698 has been found in 12 queries.
# 1196 has been found in 7 queries.
# 2499 has been found in 11 queries.
# 508 has been found in 11 queries.
# 1861 has been found in 11 queries.
# 2249 has been found in 9 queries.
# 1030 has been found in 11 queries.
# 1118 has been found in 10 queries.
# 1884 has been found in 11 queries.
# 1783 has been found in 11 queries.
# 733 has been found in 12 queries.
# 557 has been found in 8 queries.
# 105 has been found in 7 queries.
# 2312 has been found in 11 queries.
# 1068 has been found in 11 queries.
# 429 has been found in 12 queries.
# 1492 has been found in 11 queries.
# 1278 has been found in 8 queries.
# 2601 has been found in 12 queries.
# 2191 has been found in 9 queries.
# 2341 has been found in 10 queries.
# 1403 has been found in 12 queries.
# 573 has been found in 11 queries.
# 1341 has been found in 11 queries.
# 696 has been found in 11 queries.
# 8 has been found in 10 queries.
# 1458 has been found in 11 queries.
# 2477 has been found in 12 queries.
# 2571 has been found in 12 queries.
# 169 has been found in 8 queries.
# 215 has been found in 11 queries.
# 648 has been found in 12 queries.
# 265 has been found in 9 queries.
# 980 has been found in 10 queries.
# 2733 has been found in 12 queries.
# 2537 has been found in 12 queries.
# 1425 has been found in 10 queries.
# 789 has been found in 9 queries.
# 2031 has been found in 9 queries.
# 2024 has been found in 12 queries.
# 2398 has been found in 11 queries.
# 1667 has been found in 12 queries.
# 2966 has been found in 10 queries.
# 2215 has been found in 11 queries.
# 1569 has been found in 12 queries.
# 329 has been found in 10 queries.
# 1412 has been found in 10 queries.
# 1475 has been found in 12 queries.
# 279 has been found in 12 queries.
# 2253 has been found in 12 queries.
# 1552 has been found in 10 queries.
# 1622 has been found in 11 queries.
# 2244 has been found in 12 queries.
# 2318 has been found in 11 queries.
# 316 has been found in 12 queries.
# 756 has been found in 11 queries.
# 258 has been found in 10 queries.
# 1271 has been found in 12 queries.
# 1240 has been found in 11 queries.
# 671 has been found in 12 queries.
# 1868 has been found in 11 queries.
# 3111 has been found in 8 queries.
# 3034 has been found in 11 queries.
# 1078 has been found in 12 queries.
# 2993 has been found in 11 queries.
# 3063 has been found in 12 queries.
# 623 has been found in 12 queries.
# 2537 has been found in 12 queries.
# 1696 has been found in 10 queries.
# 1554 has been found in 10 queries.
# 1711 has been found in 11 queries.
# 2574 has been found in 12 queries.
# 1409 has been found in 9 queries.
# 3086 has been found in 9 queries.
# 2234 has been found in 11 queries.
# 2089 has been found in 12 queries.
# 702 has been found in 8 queries.
# 1626 has been found in 12 queries.
# 1879 has been found in 12 queries.
# 1466 has been found in 11 queries.
# 3270 has been found in 12 queries.
# 3154 has been found in 12 queries.
# 3355 has been found in 12 queries.
# 1233 has been found in 11 queries.
# 188 has been found in 11 queries.
# 905 has been found in 11 queries.
# 49 has been found in 12 queries.
# 2231 has been found in 11 queries.
# 1376 has been found in 11 queries.
# 2863 has been found in 11 queries.
# 2280 has been found in 12 queries.
# 2303 has been found in 12 queries.
# 2946 has been found in 12 queries.
# 2664 has been found in 11 queries.
# 3181 has been found in 12 queries.
# 1879 has been found in 10 queries.
# 1322 has been found in 12 queries.
# 2115 has been found in 9 queries.
# 2136 has been found in 5 queries.
# 1846 has been found in 11 queries.
# 175 has been found in 9 queries.
# 957 has been found in 12 queries.
# 395 has been found in 10 queries.
# 67 has been found in 10 queries.
# 603 has been found in 12 queries.
# 2623 has been found in 11 queries.
# 345 has been found in 12 queries.
# 3073 has been found in 12 queries.
# 289 has been found in 11 queries.
# 255 has been found in 10 queries.
# 86 has been found in 7 queries.
# 1262 has been found in 9 queries.
# 1866 has been found in 10 queries.
# 3073 has been found in 12 queries.
# 2673 has been found in 10 queries.
# 933 has been found in 12 queries.
# 2363 has been found in 12 queries.
# 2304 has been found in 11 queries.
# 476 has been found in 12 queries.
# 2009 has been found in 9 queries.
# 1833 has been found in 11 queries.
# 736 has been found in 10 queries.
# 2223 has been found in 11 queries.
# 3192 has been found in 12 queries.
# 2719 has been found in 11 queries.
# 2888 has been found in 12 queries.
# 3650 has been found in 12 queries.
# 3602 has been found in 12 queries.
# 2426 has been found in 11 queries.
# 144 has been found in 12 queries.
# 78 has been found in 10 queries.
# 3456 has been found in 8 queries.
# 798 has been found in 9 queries.
# 1324 has been found in 11 queries.
# 961 has been found in 11 queries.
# 831 has been found in 12 queries.
# 3168 has been found in 11 queries.
# 1826 has been found in 8 queries.
# 1604 has been found in 10 queries.
# 57 has been found in 12 queries.
# 494 has been found in 12 queries.
# 2514 has been found in 8 queries.
# 260 has been found in 10 queries.
# 685 has been found in 12 queries.
# 2905 has been found in 9 queries.
# 2916 has been found in 12 queries.
# 3271 has been found in 12 queries.
# 1496 has been found in 9 queries.
# 590 has been found in 11 queries.
# 1016 has been found in 9 queries.
# 51 has been found in 12 queries.
# 3061 has been found in 10 queries.
# 955 has been found in 12 queries.
# 241 has been found in 10 queries.
# 2129 has been found in 11 queries.
# 3507 has been found in 12 queries.
# 2137 has been found in 11 queries.
# 2078 has been found in 10 queries.
# 2839 has been found in 12 queries.
# 3326 has been found in 11 queries.
# 712 has been found in 12 queries.
# 3323 has been found in 12 queries.
# 699 has been found in 10 queries.
# 847 has been found in 12 queries.
# 3331 has been found in 12 queries.
# 2191 has been found in 12 queries.
# 1637 has been found in 11 queries.
# 4159 has been found in 10 queries.
# 475 has been found in 11 queries.
# 849 has been found in 12 queries.
# 1852 has been found in 11 queries.
# 2410 has been found in 11 queries.
# 1855 has been found in 12 queries.
# 16 has been found in 13 queries.
# 1830 has been found in 11 queries.
# 1861 has been found in 11 queries.
# 4189 has been found in 11 queries.
# 584 has been found in 12 queries.
# 2166 has been found in 11 queries.
# 2271 has been found in 10 queries.
# 1258 has been found in 12 queries.
# 2967 has been found in 10 queries.
# 349 has been found in 12 queries.
# 4383 has been found in 13 queries.
# 2281 has been found in 11 queries.
# 3400 has been found in 9 queries.
# 2122 has been found in 11 queries.
# 2498 has been found in 10 queries.
# 2903 has been found in 12 queries.
# 3826 has been found in 12 queries.
# 1318 has been found in 11 queries.
# 2530 has been found in 4 queries.
# 760 has been found in 11 queries.
# 4596 has been found in 11 queries.
# 2275 has been found in 12 queries.
# 1960 has been found in 12 queries.
# 3415 has been found in 11 queries.
# 3075 has been found in 10 queries.
# 4179 has been found in 12 queries.
# 1954 has been found in 11 queries.
# 1536 has been found in 12 queries.
# 474 has been found in 13 queries.
# 3041 has been found in 11 queries.
# 4261 has been found in 12 queries.
# 2924 has been found in 12 queries.
# 70 has been found in 11 queries.
# 2816 has been found in 9 queries.
# 865 has been found in 10 queries.
# 789 has been found in 11 queries.
# 3309 has been found in 11 queries.
# 1249 has been found in 11 queries.
# 3694 has been found in 11 queries.
# 274 has been found in 8 queries.
# 2691 has been found in 11 queries.
# 388 has been found in 12 queries.
# 1703 has been found in 12 queries.
# 4189 has been found in 9 queries.
# 1101 has been found in 12 queries.
# 538 has been found in 12 queries.
# 3653 has been found in 12 queries.
# 1718 has been found in 13 queries.
# 2495 has been found in 12 queries.
# 4486 has been found in 11 queries.
# 1001 has been found in 12 queries.
# 764 has been found in 13 queries.
# 3414 has been found in 9 queries.
# 3813 has been found in 12 queries.
# 3687 has been found in 13 queries.
# 579 has been found in 11 queries.
# 3533 has been found in 13 queries.
# 168 has been found in 12 queries.
# 3502 has been found in 11 queries.
# 1571 has been found in 12 queries.
# 2803 has been found in 11 queries.
# 290 has been found in 12 queries.
# 4785 has been found in 11 queries.
# 4431 has been found in 13 queries.
# 4494 has been found in 12 queries.
# 2298 has been found in 10 queries.
# 2823 has been found in 12 queries.
# 3719 has been found in 9 queries.
# 4478 has been found in 11 queries.
# 2083 has been found in 10 queries.
# 3113 has been found in 11 queries.
# 3242 has been found in 11 queries.
# 905 has been found in 9 queries.
# 4153 has been found in 11 queries.
# 2866 has been found in 13 queries.
# 4632 has been found in 11 queries.
# 2856 has been found in 13 queries.
# 573 has been found in 12 queries.
# 3800 has been found in 12 queries.
# 1683 has been found in 11 queries.
# 4611 has been found in 11 queries.
# 239 has been found in 13 queries.
# 3441 has been found in 9 queries.
# 2358 has been found in 12 queries.
# 3172 has been found in 10 queries.
# 169 has been found in 11 queries.
# 3513 has been found in 12 queries.
# 1733 has been found in 12 queries.
# 2216 has been found in 13 queries.
# 3620 has been found in 12 queries.
# 3302 has been found in 11 queries.
# 1212 has been found in 12 queries.
# 3363 has been found in 12 queries.
# 4779 has been found in 13 queries.
# 3700 has been found in 13 queries.
# 3257 has been found in 13 queries.
# 4194 has been found in 13 queries.
# 444 has been found in 12 queries.
# 1452 has been found in 10 queries.
# 136 has been found in 12 queries.
# 1789 has been found in 12 queries.
# 1952 has been found in 12 queries.
# 1899 has been found in 11 queries.
# 4461 has been found in 11 queries.
# 4413 has been found in 12 queries.
# 2913 has been found in 13 queries.
# 200 has been found in 12 queries.
# 4810 has been found in 11 queries.
# 2416 has been found in 12 queries.
# 94 has been found in 9 queries.
# 2137 has been found in 12 queries.
# 5098 has been found in 11 queries.
# 1066 has been found in 13 queries.
# 2959 has been found in 13 queries.
# 3782 has been found in 11 queries.
# 1983 has been found in 12 queries.
# 3308 has been found in 12 queries.
# 1458 has been found in 13 queries.
# 472 has been found in 7 queries.
# 1879 has been found in 12 queries.
# 3352 has been found in 13 queries.
# 5484 has been found in 12 queries.
# 2907 has been found in 13 queries.
# 442 has been found in 12 queries.
# 3447 has been found in 12 queries.
# 4119 has been found in 11 queries.
# 4457 has been found in 13 queries.
# 3361 has been found in 10 queries.
# 4113 has been found in 11 queries.
# 123 has been found in 13 queries.
# 4596 has been found in 9 queries.
# 3060 has been found in 9 queries.
# 1391 has been found in 12 queries.
# 2843 has been found in 10 queries.
# 5658 has been found in 13 queries.
# 4668 has been found in 10 queries.
# 2756 has been found in 11 queries.
# 2870 has been found in 13 queries.
# 827 has been found in 13 queries.
# 897 has been found in 13 queries.
# 3173 has been found in 12 queries.
# 3676 has been found in 13 queries.
# 5142 has been found in 12 queries.
# 2207 has been found in 9 queries.
# 1446 has been found in 11 queries.
# 2074 has been found in 11 queries.
# 2057 has been found in 11 queries.
# 2634 has been found in 11 queries.
# 5795 has been found in 13 queries.
# 214 has been found in 9 queries.
# 2464 has been found in 8 queries.
# 975 has been found in 11 queries.
# 2554 has been found in 12 queries.
# 5279 has been found in 12 queries.
# 5814 has been found in 11 queries.
# 2028 has been found in 11 queries.
# 30 has been found in 13 queries.
# 1086 has been found in 13 queries.
# 2829 has been found in 13 queries.
# 2752 has been found in 9 queries.
# 1382 has been found in 12 queries.
# 941 has been found in 10 queries.
# 5184 has been found in 10 queries.
# 4009 has been found in 11 queries.
# 2927 has been found in 13 queries.
# 1792 has been found in 12 queries.
# 3714 has been found in 12 queries.
# 3429 has been found in 12 queries.
# 752 has been found in 12 queries.
# 4457 has been found in 10 queries.
# 1485 has been found in 11 queries.
# 952 has been found in 5 queries.
# 5212 has been found in 13 queries.
# 3753 has been found in 13 queries.
# 5542 has been found in 13 queries.
# 3783 has been found in 13 queries.
# 278 has been found in 13 queries.
# 5239 has been found in 13 queries.
# 5658 has been found in 12 queries.
# 3906 has been found in 6 queries.
# 3612 has been found in 13 queries.
# 246 has been found in 13 queries.
# 3861 has been found in 9 queries.
# 3041 has been found in 11 queries.
# 1299 has been found in 13 queries.
# 5229 has been found in 13 queries.
# 1750 has been found in 13 queries.
# 75 has been found in 11 queries.
# 4048 has been found in 10 queries.
# 6068 has been found in 11 queries.
# 6231 has been found in 12 queries.
# 2047 has been found in 12 queries.
# 2547 has been found in 13 queries.
# 5965 has been found in 13 queries.
# 4504 has been found in 13 queries.
# 6120 has been found in 10 queries.
# 5719 has been found in 13 queries.
# 6128 has been found in 13 queries.
# 5150 has been found in 11 queries.
# 5419 has been found in 12 queries.
# 4396 has been found in 13 queries.
# 2145 has been found in 11 queries.
# 2529 has been found in 13 queries.
# 5011 has been found in 9 queries.
# 2510 has been found in 13 queries.
# 5386 has been found in 9 queries.
# 3667 has been found in 10 queries.
# 1813 has been found in 13 queries.
# 2435 has been found in 13 queries.
# 5425 has been found in 12 queries.
# 3795 has been found in 12 queries.
# 4240 has been found in 13 queries.
# 5429 has been found in 13 queries.
# 3635 has been found in 10 queries.
# 6420 has been found in 12 queries.
# 4183 has been found in 11 queries.
# 1062 has been found in 13 queries.
# 4489 has been found in 13 queries.
# 2572 has been found in 13 queries.
# 2936 has been found in 10 queries.
# 857 has been found in 13 queries.
# 692 has been found in 13 queries.
# 5562 has been found in 13 queries.
# 5776 has been found in 13 queries.
# 3477 has been found in 12 queries.
# 2992 has been found in 11 queries.
# 4258 has been found in 10 queries.
# 3180 has been found in 12 queries.
# 11 has been found in 13 queries.
# 2848 has been found in 12 queries.
# 6586 has been found in 13 queries.
# 1225 has been found in 13 queries.
# 4799 has been found in 13 queries.
# 5061 has been found in 12 queries.
# 4636 has been found in 13 queries.
# 6090 has been found in 12 queries.
# 1809 has been found in 13 queries.
# 3182 has been found in 12 queries.
# 5918 has been found in 13 queries.
# 2616 has been found in 12 queries.
# 2814 has been found in 7 queries.
# 3851 has been found in 12 queries.
# 3939 has been found in 11 queries.
# 5381 has been found in 12 queries.
# 1084 has been found in 13 queries.
# 4901 has been found in 13 queries.
# 5335 has been found in 12 queries.
# 4960 has been found in 13 queries.
# 6718 has been found in 8 queries.
# 5452 has been found in 11 queries.
# 2103 has been found in 13 queries.
# 350 has been found in 8 queries.
# 1178 has been found in 10 queries.
# 3057 has been found in 9 queries.
# 4584 has been found in 12 queries.
# 5033 has been found in 12 queries.
# 4135 has been found in 9 queries.
# 3292 has been found in 13 queries.
# 6774 has been found in 13 queries.
# 463 has been found in 10 queries.
# 5809 has been found in 12 queries.
# 2329 has been found in 10 queries.
# 1685 has been found in 12 queries.
# 5494 has been found in 8 queries.
# 3736 has been found in 13 queries.
# 655 has been found in 5 queries.
# 4097 has been found in 13 queries.
# 1604 has been found in 10 queries.
# 5566 has been found in 13 queries.
# 1322 has been found in 12 queries.
# 5617 has been found in 11 queries.
# 3916 has been found in 12 queries.
# 212 has been found in 12 queries.
# 2176 has been found in 12 queries.
# 3538 has been found in 11 queries.
# 4779 has been found in 13 queries.
# 4070 has been found in 13 queries.
# 6401 has been found in 11 queries.
# 69 has been found in 12 queries.
# 3915 has been found in 10 queries.
# 2104 has been found in 11 queries.
# 6160 has been found in 13 queries.
# 6685 has been found in 10 queries.
# 6950 has been found in 12 queries.
# 6591 has been found in 13 queries.
# 3334 has been found in 11 queries.
# 6486 has been found in 12 queries.
# 4624 has been found in 13 queries.
# 3819 has been found in 13 queries.
# 6130 has been found in 7 queries.
# 1517 has been found in 10 queries.
# 4173 has been found in 13 queries.
# 2068 has been found in 13 queries.
# 526 has been found in 13 queries.
# 5178 has been found in 12 queries.
# 4057 has been found in 13 queries.
# 4659 has been found in 13 queries.
# 4368 has been found in 10 queries.
# 1006 has been found in 13 queries.
# 4380 has been found in 12 queries.
# 3855 has been found in 12 queries.
# 761 has been found in 13 queries.
# 5436 has been found in 11 queries.
# 3647 has been found in 13 queries.
# 4130 has been found in 12 queries.
# 7048 has been found in 13 queries.
# 5215 has been found in 9 queries.
# 5676 has been found in 12 queries.
# 4084 has been found in 11 queries.
# 1993 has been found in 8 queries.
# 7243 has been found in 12 queries.
# 6078 has been found in 12 queries.
# 7032 has been found in 13 queries.
# 3450 has been found in 13 queries.
# 5304 has been found in 11 queries.
# 2274 has been found in 13 queries.
# 6617 has been found in 12 queries.
# 3229 has been found in 12 queries.
# 3334 has been found in 11 queries.
# 2181 has been found in 12 queries.
# 305 has been found in 13 queries.
# 5818 has been found in 12 queries.
# 6591 has been found in 13 queries.
# 4526 has been found in 12 queries.
# 4982 has been found in 11 queries.
# 2107 has been found in 12 queries.
# 360 has been found in 12 queries.
# 2674 has been found in 13 queries.
# 5363 has been found in 10 queries.
# 4369 has been found in 10 queries.
# 7631 has been found in 13 queries.
# 7443 has been found in 13 queries.
# 3978 has been found in 12 queries.
# 4930 has been found in 13 queries.
# 4780 has been found in 8 queries.
# 5595 has been found in 13 queries.
# 3232 has been found in 12 queries.
# 1806 has been found in 11 queries.
# 5982 has been found in 12 queries.
# 2730 has been found in 13 queries.
# 1769 has been found in 11 queries.
# 7491 has been found in 13 queries.
# 5536 has been found in 10 queries.
# 5496 has been found in 12 queries.
# 702 has been found in 11 queries.
# 4513 has been found in 12 queries.
# 4374 has been found in 11 queries.
# 6091 has been found in 13 queries.
# 324 has been found in 12 queries.
# 1003 has been found in 13 queries.
# 3408 has been found in 9 queries.
# 7456 has been found in 12 queries.
# 4107 has been found in 12 queries.
# 7298 has been found in 12 queries.
# 1674 has been found in 12 queries.
# 3725 has been found in 13 queries.
# 1610 has been found in 10 queries.
# 3763 has been found in 7 queries.
# 7422 has been found in 13 queries.
# 797 has been found in 11 queries.
# 7843 has been found in 13 queries.
# 5647 has been found in 10 queries.
# 4481 has been found in 12 queries.
# 104 has been found in 11 queries.
# 3338 has been found in 11 queries.
# 7515 has been found in 13 queries.
# 1035 has been found in 12 queries.
# 7437 has been found in 12 queries.
# 5886 has been found in 13 queries.
# 6225 has been found in 10 queries.
# 4531 has been found in 10 queries.
# 390 has been found in 11 queries.
# 3410 has been found in 13 queries.
# 6483 has been found in 13 queries.
# 7855 has been found in 13 queries.
# 358 has been found in 13 queries.
# 3557 has been found in 9 queries.
# 1759 has been found in 11 queries.
# 5993 has been found in 13 queries.
# 5033 has been found in 11 queries.
# 3861 has been found in 13 queries.
# 3420 has been found in 12 queries.
# 2251 has been found in 12 queries.
# 3379 has been found in 13 queries.
# 7266 has been found in 11 queries.
# 634 has been found in 12 queries.
# 6055 has been found in 13 queries.
# 7651 has been found in 13 queries.
# 4058 has been found in 10 queries.
# 7214 has been found in 10 queries.
# 54 has been found in 12 queries.
# 1470 has been found in 13 queries.
# 2002 has been found in 12 queries.
# 6001 has been found in 13 queries.
# 2688 has been found in 8 queries.
# 8093 has been found in 12 queries.
# 2944 has been found in 11 queries.
# 7609 has been found in 10 queries.
# 6145 has been found in 13 queries.
# 3509 has been found in 13 queries.
# 6082 has been found in 12 queries.
# 5370 has been found in 13 queries.
# 3713 has been found in 13 queries.
# 2123 has been found in 10 queries.
# 7220 has been found in 13 queries.
# 4250 has been found in 13 queries.
# 6773 has been found in 13 queries.
# 4295 has been found in 13 queries.
# 723 has been found in 13 queries.
# 4320 has been found in 13 queries.
# 6483 has been found in 12 queries.
# 3644 has been found in 13 queries.
# 4987 has been found in 13 queries.
# 5433 has been found in 13 queries.
# 4029 has been found in 13 queries.
# 7394 has been found in 13 queries.
# 6739 has been found in 13 queries.
# 7989 has been found in 12 queries.
# 3376 has been found in 13 queries.
# 4421 has been found in 13 queries.
# 29 has been found in 13 queries.
# 3476 has been found in 13 queries.
# 298 has been found in 12 queries.
# 8283 has been found in 11 queries.
# 7880 has been found in 13 queries.
# 1704 has been found in 12 queries.
# 8146 has been found in 12 queries.
# 785 has been found in 12 queries.
# 3214 has been found in 13 queries.
# 8264 has been found in 12 queries.
# 4867 has been found in 13 queries.
# 551 has been found in 10 queries.
# 1229 has been found in 13 queries.
# 7519 has been found in 12 queries.
# 7282 has been found in 13 queries.
# 1372 has been found in 12 queries.
# 2430 has been found in 12 queries.
# 6464 has been found in 10 queries.
# 8624 has been found in 12 queries.
# 571 has been found in 13 queries.
# 5373 has been found in 11 queries.
# 4846 has been found in 13 queries.
# 6595 has been found in 13 queries.
# 5266 has been found in 10 queries.
# 4594 has been found in 13 queries.
# 7163 has been found in 12 queries.
# 1523 has been found in 11 queries.
# 3136 has been found in 12 queries.
# 2722 has been found in 10 queries.
# 4757 has been found in 13 queries.
# 3874 has been found in 9 queries.
# 682 has been found in 13 queries.
# 2471 has been found in 11 queries.
# 3465 has been found in 14 queries.
# 1344 has been found in 13 queries.
# 6581 has been found in 11 queries.
# 6793 has been found in 13 queries.
# 4231 has been found in 13 queries.
# 8821 has been found in 13 queries.
# 7900 has been found in 12 queries.
# 5459 has been found in 13 queries.
# 1133 has been found in 13 queries.
# 3671 has been found in 14 queries.
# 7169 has been found in 14 queries.
# 475 has been found in 12 queries.
# 2001 has been found in 14 queries.
# 3323 has been found in 13 queries.
# 3922 has been found in 11 queries.
# 4434 has been found in 12 queries.
# 4007 has been found in 13 queries.
# 8130 has been found in 13 queries.
# 2442 has been found in 10 queries.
# 5216 has been found in 12 queries.
# 4603 has been found in 13 queries.
# 4836 has been found in 13 queries.
# 3328 has been found in 13 queries.
# 5697 has been found in 13 queries.
# 3498 has been found in 14 queries.
# 7108 has been found in 5 queries.
# 5287 has been found in 12 queries.
# 43 has been found in 14 queries.
# 5335 has been found in 9 queries.
# 5207 has been found in 13 queries.
# 3785 has been found in 11 queries.
# 3998 has been found in 13 queries.
# 4492 has been found in 13 queries.
# 8118 has been found in 13 queries.
# 8134 has been found in 13 queries.
# 1713 has been found in 13 queries.
# 5375 has been found in 11 queries.
# 2752 has been found in 13 queries.
# 9250 has been found in 12 queries.
# 3992 has been found in 13 queries.
# 8490 has been found in 13 queries.
# 384 has been found in 11 queries.
# 946 has been found in 13 queries.
# 5106 has been found in 11 queries.
# 9184 has been found in 11 queries.
# 670 has been found in 14 queries.
# 4785 has been found in 13 queries.
# 6320 has been found in 12 queries.
# 7077 has been found in 13 queries.
# 5580 has been found in 5 queries.
# 1280 has been found in 12 queries.
# 8727 has been found in 10 queries.
# 1725 has been found in 13 queries.
# 7460 has been found in 14 queries.
# 7464 has been found in 13 queries.
# 7403 has been found in 13 queries.
# 9210 has been found in 11 queries.
# 4933 has been found in 14 queries.
# 2737 has been found in 13 queries.
# 5469 has been found in 13 queries.
# 6630 has been found in 14 queries.
# 7639 has been found in 12 queries.
# 6430 has been found in 13 queries.
# 3262 has been found in 13 queries.
# 7268 has been found in 13 queries.
# 252 has been found in 13 queries.
# 9192 has been found in 10 queries.
# 3907 has been found in 14 queries.
# 1676 has been found in 10 queries.
# 2853 has been found in 11 queries.
# 2680 has been found in 9 queries.
# 3634 has been found in 13 queries.
# 8449 has been found in 14 queries.
# 2155 has been found in 9 queries.
# 3242 has been found in 9 queries.
# 7967 has been found in 9 queries.
# 7836 has been found in 8 queries.
# 3693 has been found in 13 queries.
# 3905 has been found in 11 queries.
# 9224 has been found in 9 queries.
# 8553 has been found in 12 queries.
# 6226 has been found in 11 queries.
# 2276 has been found in 11 queries.
# 2965 has been found in 12 queries.
# 1224 has been found in 13 queries.
# 5795 has been found in 8 queries.
# 1094 has been found in 13 queries.
# 5603 has been found in 12 queries.
# 8270 has been found in 13 queries.
# 8359 has been found in 12 queries.
# 5172 has been found in 12 queries.
# 1336 has been found in 13 queries.
# 2881 has been found in 13 queries.
# 3355 has been found in 13 queries.
# 561 has been found in 13 queries.
# 2491 has been found in 11 queries.
# 3022 has been found in 8 queries.
# 9280 has been found in 4 queries.
# 6418 has been found in 13 queries.
# 2106 has been found in 13 queries.
# 7963 has been found in 14 queries.
# 1568 has been found in 13 queries.
# 3279 has been found in 11 queries.
# 1958 has been found in 13 queries.
# 1322 has been found in 14 queries.
# 523 has been found in 13 queries.
# 2245 has been found in 11 queries.
# []

# %% [markdown]
# ### **Problem  #2.6**
#
# **Together**, let's see how the performance of binary and linear search change when the order of items in the list is random using the `random.sample(...)` function. We will do this in 3 steps:
#
# 1. Rewrite the `linear_search` function so that the list is randomly ordered.
# 2. Rewrite the `binary_search` function so that the list is randomly ordered.
# 3. Graph the average number of queries for both search algorithms.
#
# ---

# %% [markdown]
# ##### **Problem 2.6.1**
# Rewrite the `linear_search` function so that the list is randomly ordered.

# %%
def linear_search(n):

  number_trials = 10
  worst_query = 0
  list_items = random.sample(range(n), n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# #### **Problem #2.6.2**
# Rewrite the `binary_search` function so that the list is randomly ordered.

# %%
def binary_search(n):

  number_trials = 10
  worst_query = 0
  list_items = random.sample(range(n), n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)

    left = 0
    right = len(list_items) - 1

    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      middle = int((left + right)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle] < marked_item:
        left = middle
      else:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# #### **Problem #2.6.3**
# Graph the average number of queries for both search algorithms.

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]
  binary_queries += [binary_search(n)]

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# []

# %% [markdown]
# #End of Lab
# ---
# © 2024 The Coding School, All rights reserved
